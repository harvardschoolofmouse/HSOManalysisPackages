# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-03-04_1413) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %% [markdown]
# ## Accomplishments: hazard works, have fixed error prop and baseline
#
# Previously, we showed hazard fits great on DA+Hx2sec_200ms fits across sessions, effect erased by shuffling the model inputs (See 2021-2-23 ipynbs from Rig3, 2021-2-21 SHUFFLEDAhx only test logit and hazard Rig1.ipynb)
#
# Now we have updated the error propagation, changed to logit from probit, and added dev explained. (see 4. Constructing a final probabilistic decoding model.pptx)
#
# ### Starting with Canonical dataset, we will fit the updated model on a variety of model formats...

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 75:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %%
runID = "3-2-21_allMICE"
pathIDx = []
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
compositesavepath="N:\\Assad Lab\\allison\\Collated Analyses\\LOGIT results\\3-2-21 Fixed Error Prop"
modelpackagefunction = nestlogit_200hx_pkg#SHUFFLE_DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails, results,postprocessing) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath=compositesavepath, runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for nestlogit_200hx3-2-21_allMICE
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# ...

# %%
bootlogit_postprocessingfunction1(results, compositesavepath, modelpackagefunction, runID=runID)
# Out:
# "     WARNING: Using new combine_th_across_sessions 3/2/2021"
# Hx2s
# Hx2s_1-6s
# Hx2s_1-4s
# Hx2s_1-2s
# Hx2s_1s
# Hx2s_-8s
# Hx2s_-6s
# Hx2s_-4s
# Hx2s_-2s
# Hx2s_-2s_DA
# Figs saved to:N:\Assad Lab\allison\Collated Analyses\LOGIT results\3-2-21 Fixed Error Prop
# "     WARNING: using new combine_AICBIC_across_sessions2 that propagates error across sessions"
# meanAIC nsesh=98 iters=100 best=[830.9273224026946]
# meanAICc nsesh=98 iters=100 best=[831.6397019214312]
# meanBIC nsesh=98 iters=100 best=[866.1021793434197]
# Train Accuracy nsesh=98 iters=100 best=[0.6070539952411735]
# Test Accuracy nsesh=98 iters=100 best=[0.5656291264933253]
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# ...

# %%
filename="COMPOSITE98"
(hazs_COMPOSITE,lts_COMPOSITE,seshCodes_COMPOSITE) = composite_fit_hazard(results; seshNos=1:98, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=compositesavepath);
figname="COMPOSITE98"
haz_results_composite(hazs_COMPOSITE, lts_COMPOSITE, seshCodes_COMPOSITE; ndp_per_sample=50, normalize=true, figname=figname, figurePath=compositesavepath)
# Out:
#    *---------- (1/98) 03/04/21 11:33:264
# ArgumentError: column name :modelData not found in the data frame
#
# Stacktrace:
#  [1] lookupname at C:\Users\AssadLab\.julia\packages\DataFrames\S3ZFo\src\other\index.jl:250 [inlined]
#  [2] getindex at C:\Users\AssadLab\.julia\packages\DataFrames\S3ZFo\src\other\index.jl:259 [inlined]
#  [3] getindex(::DataFrame, ::typeof(!), ::Symbol) at C:\Users\AssadLab\.julia\packages\DataFrames\S3ZFo\src\dataframe\dataframe.jl:361
#  [4] getproperty(::DataFrame, ::Symbol) at C:\Users\AssadLab\.julia\packages\DataFrames\S3ZFo\src\abstractdataframe\abstractdataframe.jl:295
#  [5] get_prior(::DataFrame, ::Int64, ::Symbol) at C:\Users\AssadLab\Documents\GitHub\HSOManalysisPackages\JuliaLanguage_Hierarchical_Models\function_library\hazard_modules.jl:25
# ...

# %%
runID = "3-4-21_allMICE"
pathIDx = []
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
compositesavepath="N:\\Assad Lab\\allison\\Collated Analyses\\LOGIT results\\3-4-21 Nested DA and Hx w DA alone"
modelpackagefunction = nestlogit_200hx_pkg#SHUFFLE_DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails2, results2,postprocessing2) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath=compositesavepath, runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for nestlogit_200hx3-4-21_allMICE
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# ...

# %%
bootlogit_postprocessingfunction1(results2, compositesavepath, modelpackagefunction, runID=runID)
# Out:
# "     WARNING: Using new combine_th_across_sessions 3/2/2021"
# DA
# Hx2s
# Hx2s_1-6s
# Hx2s_1-4s
# Hx2s_1-2s
# Hx2s_1s
# Hx2s_-8s
# Hx2s_-6s
# Hx2s_-4s
# Hx2s_-2s
# Hx2s_-2s_DA
# Figs saved to:N:\Assad Lab\allison\Collated Analyses\LOGIT results\3-4-21 Nested DA and Hx w DA alone
# "     WARNING: using new combine_AICBIC_across_sessions2 that propagates error across sessions"
# meanAIC nsesh=98 iters=100 best=[831.0458327627629]
# meanAICc nsesh=98 iters=100 best=[831.7577121659139]
# meanBIC nsesh=98 iters=100 best=[841.9763774616526]
# Train Accuracy nsesh=98 iters=100 best=[0.606976560490461]
# Test Accuracy nsesh=98 iters=100 best=[0.5652795712965322]
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# ...

# %%
runID = "3-4-21_allMICE"
pathIDx = []
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
compositesavepath="N:\\Assad Lab\\allison\\Collated Analyses\\LOGIT results\\3-4-21 Full DA Hx and Hazard"
modelpackagefunction = DAHxmodel_logit_200hx_pkg#SHUFFLE_DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails_haz, results_haz,postprocessing_haz) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath=compositesavepath, runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for DAHxmodel_logit_200hx_pkg3-4-21_allMICE
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# ...

# %%
filename="COMPOSITE98_haz"
(hazs_COMPOSITE,lts_COMPOSITE,seshCodes_COMPOSITE) = composite_fit_hazard(results_haz; seshNos=1:98, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=compositesavepath);
figname="COMPOSITE98_haz"
haz_results_composite(hazs_COMPOSITE, lts_COMPOSITE, seshCodes_COMPOSITE; ndp_per_sample=50, normalize=true, figname=figname, figurePath=compositesavepath)
# Out:
#    *---------- (1/98) 03/04/21 16:16:402
# Finished:   B1SNc13  B1SNc15  B1SNc18  B1SNc19  B1SNc20  B2SNc11  B2SNc15  B2SNc17  B2SNc18  B2SNc19  B2SNc20  B2SNc21  B2SNc9  B3SNc10  B3SNc12  B3SNc14  B3SNc15  B3SNc16  B3SNc17  B3SNc18  B3SNc19  B3SNc20  B3SNc21  B3SNc8  B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9  H14SNc10  H14SNc12  H14SNc14  H14SNc16  H14SNc18  H14SNc5  H14SNc7  H14SNc8  H15SNc16  H15SNc18  H15SNc5  H15SNc7  H15SNc8  H3SNc13  H3SNc15  H3SNc17  H3SNc18  H3SNc19  H3SNc20  H3SNc7  H3SNc9  H4SNc11  H4SNc13  H4SNc15  H4SNc17  H4SNc18  H4SNc19  H4SNc20  H4SNc21  H4SNc22  H4SNc23  H4SNc24  H4SNc25  H4SNc26  H4SNc7  H4SNc9  H5SNc11  H5SNc13  H5SNc14  H5SNc15  H5SNc16  H5SNc17  H5SNc18  H5SNc19  b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9  h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8  h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9  saving...
#
# B1SNc13 Rsq=0.52
# B1SNc15 Rsq=0.489
# ...

# %%
cd(compositesavepath)
pwd()
# Out:
# "N:\\Assad Lab\\allison\\Collated Analyses\\LOGIT results\\3-4-21 Full DA Hx and Hazard"

# %% [markdown]
# # save the results!!!!!!!!

# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-03-09_0120) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl v 11:37
# math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
writeMATLAB(hazs_COMPOSITE, "hazs_COMPOSITE")
writeMATLAB(seshCodes_COMPOSITE, "seshCodes_COMPOSITE")
writeMATLAB(lts_COMPOSITE, "lts_COMPOSITE")

# %%
ndp_per_sample=50
normalize=true
# Out:
# true

# %%
writeMATLAB(ndp_per_sample, "ndp_per_sample")
writeMATLAB(normalize, "normalize")

# %%
haz_results_composite(hazs_COMPOSITE, lts_COMPOSITE, seshCodes_COMPOSITE; ndp_per_sample=50, normalize=true, figname=figname, figurePath=compositesavepath)

# %% [markdown]
# pwd()

# %%
cd(compositesavepath)
pwd()
# Out:
# "N:\\Assad Lab\\allison\\Collated Analyses\\LOGIT results\\3-4-21 Full DA Hx and Hazard"

# %%
using MAT
# Out:
# ┌ Info: Precompiling MAT [23992714-dd62-5051-b70f-ba57cb901cac]
# └ @ Base loading.jl:1278

# %%
haz_results_composite(hazs_COMPOSITE, lts_COMPOSITE, seshCodes_COMPOSITE; ndp_per_sample=50, normalize=true, figname=figname, figurePath=compositesavepath)
# Out:
# normIRTs=(98, 34)
# normhazs=(98, 1701)
# B1SNc13 Rsq=0.52
# B1SNc15 Rsq=0.489
# B1SNc18 Rsq=0.331
# B1SNc19 Rsq=0.401
# B1SNc20 Rsq=0.344
# B2SNc11 Rsq=0.76
# B2SNc15 Rsq=0.344
# B2SNc17 Rsq=0.361
# B2SNc18 Rsq=0.292
# B2SNc19 Rsq=0.749
# B2SNc20 Rsq=0.301
# B2SNc21 Rsq=0.329
# B2SNc9 Rsq=0.48
# B3SNc10 Rsq=0.545
# B3SNc12 Rsq=0.446
# B3SNc14 Rsq=0.576
# B3SNc15 Rsq=0.44
# B3SNc16 Rsq=0.53
# B3SNc17 Rsq=0.345
# B3SNc18 Rsq=0.559
# B3SNc19 Rsq=0.455
# B3SNc20 Rsq=0.25
# B3SNc21 Rsq=0.377
# B3SNc8 Rsq=0.5
# B6SNc10 Rsq=0.647
# B6SNc11 Rsq=0.431
# B6SNc12 Rsq=0.515
# B6SNc13 Rsq=0.741
# B6SNc7 Rsq=0.399
# B6SNc9 Rsq=0.502
# H14SNc10 Rsq=0.345
# H14SNc12 Rsq=0.361
# H14SNc14 Rsq=0.592
# H14SNc16 Rsq=0.446
# H14SNc18 Rsq=0.402
# H14SNc5 Rsq=0.576
# H14SNc7 Rsq=0.557
# H14SNc8 Rsq=0.512
# H15SNc16 Rsq=0.381
# H15SNc18 Rsq=0.371
# H15SNc5 Rsq=0.446
# H15SNc7 Rsq=0.426
# H15SNc8 Rsq=0.603
# H3SNc13 Rsq=0.567
# H3SNc15 Rsq=0.559
# H3SNc17 Rsq=0.566
# H3SNc18 Rsq=0.451
# H3SNc19 Rsq=0.551
# ...

# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-03-09_0056) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl v 11:37
# math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
haz_results_composite(hazs_COMPOSITE, lts_COMPOSITE, seshCodes_COMPOSITE; ndp_per_sample=50, normalize=true, figname=figname, figurePath=compositesavepath)
# Out:
# normIRTs=(98, 34)
# normhazs=(98, 1701)
# B1SNc13 Rsq=0.52
# B1SNc15 Rsq=0.489
# B1SNc18 Rsq=0.331
# B1SNc19 Rsq=0.401
# B1SNc20 Rsq=0.344
# B2SNc11 Rsq=0.76
# B2SNc15 Rsq=0.344
# B2SNc17 Rsq=0.361
# B2SNc18 Rsq=0.292
# B2SNc19 Rsq=0.749
# B2SNc20 Rsq=0.301
# B2SNc21 Rsq=0.329
# B2SNc9 Rsq=0.48
# B3SNc10 Rsq=0.545
# B3SNc12 Rsq=0.446
# B3SNc14 Rsq=0.576
# B3SNc15 Rsq=0.44
# B3SNc16 Rsq=0.53
# B3SNc17 Rsq=0.345
# B3SNc18 Rsq=0.559
# B3SNc19 Rsq=0.455
# B3SNc20 Rsq=0.25
# B3SNc21 Rsq=0.377
# B3SNc8 Rsq=0.5
# B6SNc10 Rsq=0.647
# B6SNc11 Rsq=0.431
# B6SNc12 Rsq=0.515
# B6SNc13 Rsq=0.741
# B6SNc7 Rsq=0.399
# B6SNc9 Rsq=0.502
# H14SNc10 Rsq=0.345
# H14SNc12 Rsq=0.361
# H14SNc14 Rsq=0.592
# H14SNc16 Rsq=0.446
# H14SNc18 Rsq=0.402
# H14SNc5 Rsq=0.576
# H14SNc7 Rsq=0.557
# H14SNc8 Rsq=0.512
# H15SNc16 Rsq=0.381
# H15SNc18 Rsq=0.371
# H15SNc5 Rsq=0.446
# H15SNc7 Rsq=0.426
# H15SNc8 Rsq=0.603
# H3SNc13 Rsq=0.567
# H3SNc15 Rsq=0.559
# H3SNc17 Rsq=0.566
# H3SNc18 Rsq=0.451
# H3SNc19 Rsq=0.551
# ...

# %%
runID = "3-9-21_allMICE"
pathIDx = []
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
compositesavepath="N:\\Assad Lab\\allison\\Collated Analyses\\LOGIT results\\3-9-21 Shuf FullDAHxHaz"
modelpackagefunction = SHUFFLE_DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails_haz, results_haz,postprocessing_haz) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath=compositesavepath, runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for SHUFFLE_DAHxmodel_logit_200hx_pkg3-9-21_allMICE
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# ...
