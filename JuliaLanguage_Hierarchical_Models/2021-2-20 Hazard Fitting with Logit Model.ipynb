# %%
cd("/Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "/function_library/file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-21_0013) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %% [markdown]
# ## We had good luck fitting the hazard in our practice.
#
# We have added a new set of modules for hazard fitting from "Direct fitting the hazard function 2-7-2021.ipynb"
#
# ### Canonical dataset...

# %%
runID = "dst-150_B5TEST"
collatedPath = "/Users/lilis/Dropbox (MIT)/1 ASSAD LAB/testFiles/testHOST/sessionHOST/CSVfigures/collatedCSV_doubleb5d13/sessions"
modelpackagefunction = fullmodel_ocs_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails_200, results_200,postprocessing_200) = run_collated_model(collatedPath, modelpackagefunction; 
    pathIDx = [],runFails=false, failDirs=[], 
    postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=false);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for fm_ocs_logit_200hxdst-150_B5TEST
#
# Found 2 sessions in /Users/lilis/Dropbox (MIT)/1 ASSAD LAB/testFiles/testHOST/sessionHOST/CSVfigures/collatedCSV_doubleb5d13/sessions:
# 1. b5_SNc_13
# 2. b5_SNc_13_2
# 	Using all these sessions.
#
# -----------------------------------------------
# Processing b5_SNc_13...(2021-02-20_1536)
#       *---------- (1/2) 02/20/21 15:36:799
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.0733
# 0.0733
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 477=n, the number of first-licks
#    *---------- (1/100) 02/20/21 15:37:37
#    *=--------- (10/100) 02/20/21 15:37:738
#    *==-------- (20/100) 02/20/21 15:37:882
# ***PosDefException...retrying. (1/10)
#    *===------- (30/100) 02/20/21 15:37:089
# ...

# %%
(hazfit250_2_50, p_by_trialfit250_2_50, ltfit250_2_50) = get_fit_hazard(results_200, seshNo=1, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.0038620354627155696
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=0.22026052968691287
# max p_fit=0.888353485229511
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=15.92

# %% [markdown]
# ### A tdt dataset...

# %%
runID = "dst-150_G2redTEST"
collatedPath = "/Users/lilis/Dropbox (MIT)/1 ASSAD LAB/testFiles/testHOST/sessionHOST/CSVfigures/collatedCSV"
modelpackagefunction = fullmodel_ocs_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails_red, results_red,postprocessing_red) = run_collated_model(collatedPath, modelpackagefunction; 
    pathIDx = [3],runFails=false, failDirs=[], 
    postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=false);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for fm_ocs_logit_200hxdst-150_G2redTEST
#
# Found 3 sessions in /Users/lilis/Dropbox (MIT)/1 ASSAD LAB/testFiles/testHOST/sessionHOST/CSVfigures/collatedCSV:
# 1. b5_SNc_13
# 2. b5_SNc_13_2
# 3. g2f_DLSred_13
# 	Using only a subset of these sessions:
# g2f_DLSred_13
#
# -----------------------------------------------
# Processing g2f_DLSred_13...(2021-02-20_1550)
#       *---------- (1/1) 02/20/21 15:50:038
#
# truncating data back: -0.15s
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 552=n, the number of first-licks
#    *---------- (1/100) 02/20/21 15:50:224
#    *=--------- (10/100) 02/20/21 15:50:515
#    *==-------- (20/100) 02/20/21 15:50:681
#    *===------- (30/100) 02/20/21 15:50:852
#    *====------ (40/100) 02/20/21 15:50:012
#    *=====----- (50/100) 02/20/21 15:50:154
# ...

# %%
(hazfitred_2_50, p_by_trialfitred_2_50, ltfitred_2_50) = get_fit_hazard(results_red, seshNo=1, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.0042738020579286
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=0.1782540343755487
# max p_fit=0.6808401991690385
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=17.35

# %% [markdown]
# ### Applying to more datasets...

# %%
runID = "dst-150_DAonly_G2redTEST"
collatedPath = "/Users/lilis/Dropbox (MIT)/1 ASSAD LAB/testFiles/testHOST/sessionHOST/CSVfigures/collatedCSV"
modelpackagefunction = DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails_red, results_red,postprocessing_red) = run_collated_model(collatedPath, modelpackagefunction; 
    pathIDx = [3],runFails=false, failDirs=[], 
    postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=false);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for DAHxmodel_logit_200hx_pkgdst-150_DAonly_G2redTEST
#
# Found 3 sessions in /Users/lilis/Dropbox (MIT)/1 ASSAD LAB/testFiles/testHOST/sessionHOST/CSVfigures/collatedCSV:
# 1. b5_SNc_13
# 2. b5_SNc_13_2
# 3. g2f_DLSred_13
# 	Using only a subset of these sessions:
# g2f_DLSred_13
#
# -----------------------------------------------
# Processing g2f_DLSred_13...(2021-02-21_0013)
#       *---------- (1/1) 02/21/21 00:13:808
#
# truncating data back: -0.15s
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 552=n, the number of first-licks
#    *---------- (1/100) 02/21/21 00:13:074
#    *=--------- (10/100) 02/21/21 00:13:249
#    *==-------- (20/100) 02/21/21 00:13:376
#    *===------- (30/100) 02/21/21 00:13:508
#    *====------ (40/100) 02/21/21 00:13:663
#    *=====----- (50/100) 02/21/21 00:13:792
# ...

# %%
(hazs_red,lts_red,seshCodes_red) = composite_fit_hazard(results_red; seshNos=1, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_red, lts_red, seshCodes_red; ndp_per_sample=50, normalize=true)
# Out:
#    *---------- (1/1) 02/21/21 00:14:419
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Finished:   g2fDLSred13  g2fDLSred13 Rsq=0.496
# Good fits included:
#      g2fDLSred13
# Bad fits excluded:
