# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-21_2207) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 75:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %%
runID = "dst-15_DAHx200_allMice"
pathIDx = []
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails, results,postprocessing) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# ...

# %%
filename="B5_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_B5,lts_B5,seshCodes_B5) = composite_fit_hazard(results; seshNos=B5_idx, p_prior=0.00386*2, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
# Out:
#    *---------- (1/6) 02/21/21 22:24:718
# Finished:   b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9  saving...

# %%
figname="B5_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
haz_results_composite(hazs_B5, lts_B5, seshCodes_B5; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# b5SNc13 Rsq=0.604
# b5SNc14 Rsq=0.771
# b5SNc15 Rsq=0.708
# b5SNc17 Rsq=0.402
# b5SNc19 Rsq=0.346
# b5SNc9 Rsq=0.611
# CIlower index: 1 | CIupper index: 6
# (34, 6)
# Good fits included:
#      b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9
# Bad fits excluded:

# %%
size(seshCodes_B5)
# Out:
# (6,)

# %%
filename="B6_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="B6_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_B6,lts_B6,seshCodes_B6) = composite_fit_hazard(results; seshNos=B6_idx, p_prior=0.00386*2, 
    ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
# Out:
#    *---------- (1/6) 02/21/21 22:24:809
# Finished:   B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9  saving...

# %%
figname="B6_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
haz_results_composite(hazs_B6, lts_B6, seshCodes_B6; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# B6SNc10 Rsq=0.654
# B6SNc11 Rsq=0.382
# B6SNc12 Rsq=0.508
# B6SNc13 Rsq=0.74
# B6SNc7 Rsq=0.406
# B6SNc9 Rsq=0.503
# CIlower index: 1 | CIupper index: 6
# (34, 6)
# Good fits included:
#      B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9
# Bad fits excluded:

# %%
hazs=hazs_B6[3,:]
lts=lts_B6[3,:]
seshCodes=seshCodes_B6[3,:]
ndp_per_sample =50
normalize = true

fig=figure(figsize=(12,3))
axIRT = subplot(1,3,1)
axHaz = subplot(1,3,2)
axOverlay = subplot(1,3,3)
meanIRT = []
meanHaz = []
goodidx = findall(x->!isnan(x[1]), hazs)
failidx = findall(x->isnan(x[1]), hazs)
for i=1:length(goodidx)

    ii = goodidx[i]
    sesh=seshCodes[ii]
    # get the nanmean of the vectors
    IRTbyOP = IRT_byOpportunity(lts[ii], edges=0:0.01*ndp_per_sample:17, verbose=false)   
    xs = range(0.01, step=0.01*ndp_per_sample, stop=7)
    haz=hazs[ii]
    
    if normalize
        IRTbyOP = (IRTbyOP .- nanmin(IRTbyOP[1:length(xs)])) ./ nanmax((IRTbyOP .- nanmin(IRTbyOP[1:length(xs)]))[1:length(xs)])
        haz = (haz .- nanmin(haz[1:length(xs)])) ./ nanmax((haz .- nanmin(haz[1:length(xs)]))[1:length(xs)])
    end

    println(join([seshCodes[ii], " Rsq=", round(Rsq(IRTbyOP[1:length(xs)], haz[1:length(xs)]), digits=3)]))
    xs = range(0.01, step=0.01*ndp_per_sample, stop=7)

    edges=0:0.01*ndp_per_sample:17
    axIRT.plot(edges[1:length(xs)], IRTbyOP[1:length(xs)], linewidth=0.5, "k-", label=sesh)
    axHaz.plot(xs, haz[1:length(xs)], "r-", linewidth=0.5,label=sesh)
    axOverlay.plot(edges[1:length(xs)], IRTbyOP[1:length(xs)], linewidth=0.5, "k-", label=sesh)
    axOverlay.plot(xs, haz[1:length(xs)], "r-",linewidth=0.5, label=sesh)

    if i==1
        meanIRT = IRTbyOP
        meanHaz = haz
    else
        meanIRT = hcat(meanIRT, IRTbyOP)
        meanHaz = hcat(meanHaz, haz)

    end
end
# get means:
xs = range(0.01, step=0.01*ndp_per_sample, stop=7)
edges=0:0.01*ndp_per_sample:17
meanIRT = nanmean_mat(meanIRT, 2)
meanHaz = nanmean_mat(meanHaz, 2)

h = fig.suptitle(join(["Mean Rsq=", round(Rsq(meanIRT[1:length(xs)], meanHaz[1:length(xs)]), digits=3)]), y=1.15)
axIRT.plot(edges[1:length(xs)], meanIRT[1:length(xs)], "k-", linewidth=3, label="MEAN")
axHaz.plot(xs, meanHaz[1:length(xs)], "r-", linewidth=3, label="MEAN")
axOverlay.plot(edges[1:length(xs)], meanIRT[1:length(xs)], "k-", linewidth=3, label="MEAN")
axOverlay.plot(xs, meanHaz[1:length(xs)], "r-", linewidth=3, label="MEAN")


axIRT.set_title("True Hazard")
axHaz.set_title("Fit Hazard")
axOverlay.set_title("Overlay")


#     axIRT.legend(loc="bottom", bbox_to_anchor=(0, 1.3))
#     axHaz.legend(loc="bottom", bbox_to_anchor=(0, 1.3))
#     axOverlay.legend(loc="bottom", bbox_to_anchor=(0, 1.3))
axIRT.set_xticks(0:1:7)
axHaz.set_xticks(0:1:7)
axOverlay.set_xticks(0:1:7)
axIRT.set_xlim([0,7])
axHaz.set_xlim([0,7])
axOverlay.set_xlim([0,7])
axIRT.set_xlabel("time (s)") 
axHaz.set_xlabel("time (s)") 
axOverlay.set_xlabel("time (s)") 
axIRT.set_ylabel("normalized hazard") 

# diagnostics:
println("Good fits included: ")
print("     ")
pretty_print_list(seshCodes[goodidx], orient="horizontal")
println(" ")
println("Bad fits excluded: ")
print("     ")
pretty_print_list(seshCodes[failidx], orient="horizontal")
println(" ")
# Out:
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# B6SNc12 Rsq=0.508
# Good fits included:
#      B6SNc12
# Bad fits excluded:

# %%
figure
# hist(lts_B6[3,:]);
# figure
plot(1:length(hazs_B6[3,:][1]), hazs_B6[3,:][1], ".")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000064CAB190>

# %%
filename="H6_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="H6_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_H6,lts_H6,seshCodes_H6) = composite_fit_hazard(results; seshNos=H6_idx, ndp_per_sample=50, 
    pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
haz_results_composite(hazs_H6, lts_H6, seshCodes_H6; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/12) 02/21/21 22:25:876
# Finished:   h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8  saving...
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# h6SNc14 Rsq=0.382
# h6SNc15 Rsq=0.391
# h6SNc16 Rsq=0.52
# h6SNc17 Rsq=0.459
# h6SNc18 Rsq=0.404
# h6SNc19 Rsq=0.547
# h6SNc20 Rsq=0.461
# h6SNc21 Rsq=0.364
# h6SNc5 Rsq=0.478
# h6SNc61 Rsq=0.65
# h6SNc71 Rsq=0.422
# h6SNc8 Rsq=0.498
# CIlower index: 1 | CIupper index: 12
# (34, 12)
# Good fits included:
#      h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8
# Bad fits excluded:

# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-21_2226) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
filename="H7_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="H7_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_H7,lts_H7,seshCodes_H7) = composite_fit_hazard(results; seshNos=H7_idx, ndp_per_sample=50, 
    pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
# Out:
#    *---------- (1/6) 02/21/21 22:26:609
# Finished:   h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9  saving...

# %%
haz_results_composite(hazs_H7, lts_H7, seshCodes_H7; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# h7SNc10 Rsq=0.612
# h7SNc11 Rsq=0.464
# h7SNc12 Rsq=0.531
# h7SNc13 Rsq=0.312
# h7SNc8 Rsq=0.386
# h7SNc9 Rsq=0.398
# CIlower index: 1 | CIupper index: 6
# (34, 6)
# Good fits included:
#      h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9
# Bad fits excluded:

# %%
filename="H5_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="H5_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_H5,lts_H5,seshCodes_H5) = composite_fit_hazard(results; seshNos=H5_idx, 
    ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
haz_results_composite(hazs_H5, lts_H5, seshCodes_H5; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/8) 02/21/21 22:26:644
# Finished:   H5SNc11  H5SNc13  H5SNc14  H5SNc15  H5SNc16  H5SNc17  H5SNc18  H5SNc19  saving...
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# H5SNc13 Rsq=0.493
# H5SNc14 Rsq=0.483
# H5SNc15 Rsq=0.712
# H5SNc16 Rsq=0.422
# H5SNc17 Rsq=0.448
# H5SNc18 Rsq=0.567
# H5SNc19 Rsq=0.518
# CIlower index: 1 | CIupper index: 7
# (34, 7)
# Good fits included:
#      H5SNc13  H5SNc14  H5SNc15  H5SNc16  H5SNc17  H5SNc18  H5SNc19
# Bad fits excluded:
#      H5SNc11

# %%
filename="H3_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="H3_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_H3,lts_H3,seshCodes_H3) = composite_fit_hazard(results; seshNos=H3_idx, ndp_per_sample=50, 
    pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
haz_results_composite(hazs_H3, lts_H3, seshCodes_H3; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/8) 02/21/21 22:26:29
# Finished:   H3SNc13  H3SNc15  H3SNc17  H3SNc18  H3SNc19  H3SNc20  H3SNc7  H3SNc9  saving...
#
# H3SNc13 Rsq=0.564
# H3SNc15 Rsq=0.57
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# H3SNc17 Rsq=0.557
# H3SNc18 Rsq=0.45
# H3SNc19 Rsq=0.537
# H3SNc20 Rsq=0.462
# H3SNc7 Rsq=0.454
# H3SNc9 Rsq=0.429
# CIlower index: 1 | CIupper index: 8
# (34, 8)
# Good fits included:
#      H3SNc13  H3SNc15  H3SNc17  H3SNc18  H3SNc19  H3SNc20  H3SNc7  H3SNc9
# Bad fits excluded:

# %%
filename="H4_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="H4_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_H4,lts_H4,seshCodes_H4) = composite_fit_hazard(results; seshNos=H4_idx, 
    ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
haz_results_composite(hazs_H4, lts_H4, seshCodes_H4; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/15) 02/21/21 22:26:799
#    *==-------- (3/15) 02/21/21 22:26:336
#    *====------ (6/15) 02/21/21 22:26:569
#    *======---- (9/15) 02/21/21 22:26:093
#    *========-- (12/15) 02/21/21 22:26:717
#    *========== (15/15) 02/21/21 22:26:05
# Finished:   H4SNc11  H4SNc13  H4SNc15  H4SNc17  H4SNc18  H4SNc19  H4SNc20  H4SNc21  H4SNc22  H4SNc23  H4SNc24  H4SNc25  H4SNc26  H4SNc7  H4SNc9  saving...
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# H4SNc11 Rsq=0.506
# H4SNc13 Rsq=0.444
# H4SNc15 Rsq=0.328
# H4SNc17 Rsq=0.487
# H4SNc18 Rsq=0.359
# H4SNc19 Rsq=0.352
# H4SNc20 Rsq=0.476
# H4SNc21 Rsq=0.471
# H4SNc22 Rsq=0.48
# H4SNc23 Rsq=0.475
# H4SNc24 Rsq=0.604
# H4SNc25 Rsq=0.352
# H4SNc26 Rsq=0.578
# H4SNc7 Rsq=0.421
# H4SNc9 Rsq=0.474
# CIlower index: 1 | CIupper index: 15
# (34, 15)
# Good fits included:
# ...

# %%
filename="H14_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="H14_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_H14,lts_H14,seshCodes_H14) = composite_fit_hazard(results; seshNos=H14_idx, 
    ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
haz_results_composite(hazs_H14, lts_H14, seshCodes_H14; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/8) 02/21/21 22:26:454
# Finished:   H14SNc10  H14SNc12  H14SNc14  H14SNc16  H14SNc18  H14SNc5  H14SNc7  H14SNc8  saving...
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# H14SNc10 Rsq=0.348
# H14SNc12 Rsq=0.366
# H14SNc14 Rsq=0.592
# H14SNc16 Rsq=0.442
# H14SNc18 Rsq=0.41
# H14SNc5 Rsq=0.565
# H14SNc7 Rsq=0.55
# H14SNc8 Rsq=0.525
# CIlower index: 1 | CIupper index: 8
# (34, 8)
# Good fits included:
#      H14SNc10  H14SNc12  H14SNc14  H14SNc16  H14SNc18  H14SNc5  H14SNc7  H14SNc8
# Bad fits excluded:

# %%
filename="H15_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="H15_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_H15,lts_H15,seshCodes_H15) = composite_fit_hazard(results; seshNos=H15_idx, 
    ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
haz_results_composite(hazs_H15, lts_H15, seshCodes_H15; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *==-------- (1/5) 02/21/21 22:27:807
#    *====------ (2/5) 02/21/21 22:27:616
#    *======---- (3/5) 02/21/21 22:27:312
#    *========-- (4/5) 02/21/21 22:27:403
#    *========== (5/5) 02/21/21 22:27:253
# Finished:   H15SNc16  H15SNc18  H15SNc5  H15SNc7  H15SNc8  saving...
#
# H15SNc16 Rsq=0.385
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# H15SNc18 Rsq=0.375
# H15SNc5 Rsq=0.45
# H15SNc7 Rsq=0.426
# H15SNc8 Rsq=0.6
# CIlower index: 1 | CIupper index: 5
# (34, 5)
# Good fits included:
#      H15SNc16  H15SNc18  H15SNc5  H15SNc7  H15SNc8
# Bad fits excluded:

# %%
(hazs_H15,lts_H15,seshCodes_H15) = composite_fit_hazard(results; seshNos=H15_idx, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H15, lts_H15, seshCodes_H15; ndp_per_sample=50, normalize=true)
# Out:
#    *==-------- (1/5) 02/21/21 22:27:483
#    *====------ (2/5) 02/21/21 22:27:276
#    *======---- (3/5) 02/21/21 22:27:192
#    *========-- (4/5) 02/21/21 22:27:898
#    *========== (5/5) 02/21/21 22:28:703
# Finished:   H15SNc16  H15SNc18  H15SNc5  H15SNc7  H15SNc8
# IOError: chdir : invalid argument (EINVAL)
#
# Stacktrace:
#  [1] uv_error at .\libuv.jl:97 [inlined]
#  [2] cd(::String) at .\file.jl:84
#  [3] composite_fit_hazard(::DataFrame; seshNos::UnitRange{Int64}, p_prior::Float64, ndp_per_sample::Int64, pre_normalize_p::Bool, normalize::Bool, filename::String, savepath::String) at C:\Users\AssadLab\Documents\GitHub\HSOManalysisPackages\JuliaLanguage_Hierarchical_Models\function_library\hazard_modules.jl:430
#  [4] top-level scope at In[137]:1
#  [5] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
filename="COMPOSITE98_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
figname="COMPOSITE98_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
(hazs_all,lts_all,seshCodes_all) = composite_fit_hazard(results; seshNos=1:98, ndp_per_sample=50, 
    pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
haz_results_composite(hazs_all, lts_all, seshCodes_all; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/98) 02/21/21 22:28:128
# Finished:   B1SNc13  B1SNc15  B1SNc18  B1SNc19  B1SNc20  B2SNc11  B2SNc15  B2SNc17  B2SNc18  B2SNc19  B2SNc20  B2SNc21  B2SNc9  B3SNc10  B3SNc12  B3SNc14  B3SNc15  B3SNc16  B3SNc17  B3SNc18  B3SNc19  B3SNc20  B3SNc21  B3SNc8  B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9  H14SNc10  H14SNc12  H14SNc14  H14SNc16  H14SNc18  H14SNc5  H14SNc7  H14SNc8  H15SNc16  H15SNc18  H15SNc5  H15SNc7  H15SNc8  H3SNc13  H3SNc15  H3SNc17  H3SNc18  H3SNc19  H3SNc20  H3SNc7  H3SNc9  H4SNc11  H4SNc13  H4SNc15  H4SNc17  H4SNc18  H4SNc19  H4SNc20  H4SNc21  H4SNc22  H4SNc23  H4SNc24  H4SNc25  H4SNc26  H4SNc7  H4SNc9  H5SNc11  H5SNc13  H5SNc14  H5SNc15  H5SNc16  H5SNc17  H5SNc18  H5SNc19  b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9  h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8  h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9  saving...
#
# B1SNc13 Rsq=0.543
# B1SNc15 Rsq=0.51
# ...

# %%
(hazs_all,lts_all,seshCodes_all) = composite_fit_hazard(results; seshNos=1:98, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_all, lts_all, seshCodes_all; ndp_per_sample=50, normalize=true)
# Out:
#    *---------- (1/98) 02/21/21 00:18:799
# Finished:   B1SNc13  B1SNc15  B1SNc18  B1SNc19  B1SNc20  B2SNc11  B2SNc15  B2SNc17  B2SNc18  B2SNc19  B2SNc20  B2SNc21  B2SNc9  B3SNc10  B3SNc12  B3SNc14  B3SNc15  B3SNc16  B3SNc17  B3SNc18  B3SNc19  B3SNc20  B3SNc21  B3SNc8  B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9  H14SNc10  H14SNc12  H14SNc14  H14SNc16  H14SNc18  H14SNc5  H14SNc7  H14SNc8  H15SNc16  H15SNc18  H15SNc5  H15SNc7  H15SNc8  H3SNc13  H3SNc15  H3SNc17  H3SNc18  H3SNc19  H3SNc20  H3SNc7  H3SNc9  H4SNc11  H4SNc13  H4SNc15  H4SNc17  H4SNc18  H4SNc19  H4SNc20  H4SNc21  H4SNc22  H4SNc23  H4SNc24  H4SNc25  H4SNc26  H4SNc7  H4SNc9  H5SNc11  H5SNc13  H5SNc14  H5SNc15  H5SNc16  H5SNc17  H5SNc18  H5SNc19  b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9  h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8  h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9  B1SNc13 Rsq=0.543
# B1SNc15 Rsq=0.51
# B1SNc18 Rsq=0.333
# ...

# %% [markdown]
# # need to resolve why some Rsqs are NaN and validate that we are fitting what we think we are here...
#
# Resolved, was a nanmean/nansum/nanmin/nanmax issue. Is good now. Was some sessions didn't have licks throughout 0-7s.
