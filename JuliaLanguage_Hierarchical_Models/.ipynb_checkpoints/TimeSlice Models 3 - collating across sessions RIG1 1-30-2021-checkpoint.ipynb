# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-01-30_1948) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 55:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %% [markdown]
# # attempting to run models across all B2 sessions...

# %%
runID = "dwnsample_trim-150_250smsbins_B2"
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = bootlogit_timeslice_modelpackage1
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails150_B2, results150_B2,postprocessing150_B2) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = B2_idx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for bootlogit_timeslice_modelpackage1_dwnsample_trim-150_250smsbins_B2
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# ...

# %% [markdown]
# ### Weird, B2 day 15 continues to have issues

# %%
runID = "dwnsample_trim-150_250smsbins_B2test"
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = bootlogit_timeslice_modelpackage1
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails150_B2, results150_B2,postprocessing150_B2) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = [B2_idx[2]],runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for bootlogit_timeslice_modelpackage1_dwnsample_trim-150_250smsbins_B2test
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# ...

# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-01-31_1834) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
aaa = "x_t1_fl2.3581s_B2_SNc_15.csv"
# Out:
# "x_t1_fl2.3581s_B2_SNc_15.csv"

# %%
vec(readdlm(aaa, ',', Float64, '\n'));
# Out:
# ArgumentError: Cannot open 'x_t1_fl2.3581s_B2_SNc_15.csv': not a file
#
# Stacktrace:
#  [1] readdlm_auto(::String, ::Char, ::Type{T} where T, ::Char, ::Bool; opts::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{,Tuple{}}}) at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:233
#  [2] readdlm_auto at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:233 [inlined]
#  [3] #readdlm#6 at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:225 [inlined]
#  [4] readdlm(::String, ::Char, ::Type{T} where T, ::Char) at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:225
#  [5] top-level scope at In[47]:1
#  [6] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %% [markdown]
# # There's a problem with this LOI file! There's no data... why? Exploring...

# %%
testData = extract_data("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh\\B2_SNc_15\\singletrial"; blmode=false, LOImode=false);

# %%
check_imported_data(testData; idx=1)
# Out:
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# 69
# mean: 0.016392136975000002
# median: 0.00076135305
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\singletrial
# 69

# %%
testData_bl = extract_data("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh\\B2_SNc_15\\baseline";
    blmode=true, LOImode=false);

# %%
check_imported_data(testData_bl; idx=1)
# Out:
# 69
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# mean: 0.04486437606603396
# median: 0.031633
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\baseline
# 69

# %%
testData_loi = extract_data("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh\\B2_SNc_15\\LOI"; blmode=false, LOImode=true);
# Out:
#
# "!!!!!!!!!!!!!!!!!!!!!!!!!!!!! ERROR"
# "	On path N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\LOI..."
# "blmode=false  LOImode=true"
# "i=69  ystart=243  xstart=0"
# "Could not vec(readdlm(a[xstart+i], ',', Float64, '
# '));"
# "a[xstart+i-1]=x_t19_fl1.3475s_B2_SNc_15.csv"
# "a[ystart+i-1]=y_t19_fl1.3475s_B2_SNc_15.csv"
# "a[xstart+i]=x_t1_fl2.3581s_B2_SNc_15.csv"
# "a[ystart+i]=y_t1_fl2.3581s_B2_SNc_15.csv"
# at row 0, column 0 : ArgumentError("number of rows in dims must be > 0, got 0")
#
# Stacktrace:
#  [1] error(::String) at .\error.jl:33
#  [2] dlm_fill(::DataType, ::Array{Array{Int64,1},1}, ::Tuple{Int64,Int64}, ::Bool, ::String, ::Bool, ::Char) at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:514
# ...

# %%
check_imported_data(testData_loi; idx=2)
# Out:
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# 198
# mean: -0.027811667805755395
# median: -0.028276
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_19\LOI
# 198

# %% [markdown]
# #### The problem is there's a timeshift issue with trial 1. It seems to be fine by trial 3 and trial 2 is excluded. We will delete the trial 1 data from the folder.
#
# ![B2%20debug%20d15.png](attachment:B2%20debug%20d15.png)

# %%
testData_loi = extract_data("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh\\B2_SNc_15\\LOI"; blmode=false, LOImode=true);

# %%
check_imported_data(testData_loi; idx=3)
# Out:
# 204
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# mean: -0.10992262
# median: -0.111855
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\LOI
# 204

# %%
testData = extract_data("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh\\B2_SNc_15\\singletrial"; blmode=false, LOImode=false);
testData_bl = extract_data("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh\\B2_SNc_15\\baseline";
    blmode=true, LOImode=false);

# %%
check_imported_data(testData_bl; idx=3)
# Out:
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# 204
# mean: 0.0085087027032967
# median: 0.0075788
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\baseline
# 204

# %%
check_imported_data(testData; idx=3)
# Out:
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# 204
# mean: -0.03135649611888112
# median: -0.039686
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\singletrial
# 204

# %% [markdown]
# ### Ready to try again on B2...

# %%
runID = "dwnsample_trim-150_250smsbins_B2"
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = bootlogit_timeslice_modelpackage1
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails150_B2, results150_B2,postprocessing150_B2) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = B2_idx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for bootlogit_timeslice_modelpackage1_dwnsample_trim-150_250smsbins_B2
