# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-20_1913) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 75:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %%
runID = "dst-15_full_ALLmice"
pathIDx = []
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = fullmodel_ocs_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails, results,postprocessing) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for fm_ocs_logit_200hxdst-15_full_ALLmice
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using all these sessions.
#
# -----------------------------------------------
# Processing B1_SNc_13...(2021-02-20_1610)
#       *---------- (1/98) 02/20/21 16:10:723
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.17199
# -0.17199
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 146=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_13\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1611.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_13\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1611.csv
# DataFrame
# -----------------------------------------------
# Processing B1_SNc_15...(2021-02-20_1611)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.08489
# 0.08489
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 125=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_15\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1611.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_15\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1611.csv
# DataFrame
# -----------------------------------------------
# Processing B1_SNc_18...(2021-02-20_1611)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.016095
# 0.016095
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 281=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_18\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1612.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_18\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1612.csv
# DataFrame
# -----------------------------------------------
# Processing B1_SNc_19...(2021-02-20_1612)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.015232
# -0.015232
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 478=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_19\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1613.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_19\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1613.csv
# DataFrame
# -----------------------------------------------
# Processing B1_SNc_20...(2021-02-20_1613)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.053374
# -0.053374
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 330=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_20\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1614.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_20\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1614.csv
# DataFrame
# -----------------------------------------------
# Processing B2_SNc_11...(2021-02-20_1614)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.033265
# -0.033265
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 211=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_11\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1615.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_11\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1615.csv
# DataFrame
# -----------------------------------------------
# Processing B2_SNc_15...(2021-02-20_1615)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.095219
# -0.095219
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 240=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1616.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1616.csv
# DataFrame
# -----------------------------------------------
# Processing B2_SNc_17...(2021-02-20_1616)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 102 iter=1"
# 0.027614
# 0.027614
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 147=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_17\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1616.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_17\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1616.csv
# DataFrame
# -----------------------------------------------
# Processing B2_SNc_18...(2021-02-20_1616)
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 10 iter=1"
# -0.035415
# -0.035415
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 60=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ...
# Processing h7_SNc_11...(2021-02-20_1757)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.018555
# -0.018555
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 260=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_11\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1758.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_11\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1758.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_12...(2021-02-20_1758)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0057979
# -0.0057979
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 170=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_12\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1759.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_12\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1759.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_13...(2021-02-20_1759)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.024478
# 0.024478
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 246=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_13\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1759.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_13\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1759.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_8...(2021-02-20_1759)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# 0.0022877
# 0.0022877
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1000=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_8\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1803.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_8\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1803.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_9...(2021-02-20_1803)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.014219
# -0.014219
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 919=n, the number of first-licks
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ***PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_9\results_fm_ocs_logit_200hxdst-15_full_ALLmice\th_summary_2021-02-20_1806.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_9\results_fm_ocs_logit_200hxdst-15_full_ALLmice\results_df_2021-02-20_1806.csv
# DataFrame
# -----------------------------------------------
#
# Completed procesing of 98 sessions. (2021-02-20_1806) ~
#
# 	Find results in each sessions' folder in: fm_ocs_logit_200hxdst-15_full_ALLmice
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_fm_ocs_logit_200hxdst-15_full_ALLmice
#
# -----------------------------------------------

# %%
(hazfit_B1_SNc_18, p_by_trialfit_B1_SNc_18, ltfit_B1_SNc_18) = get_fit_hazard(results, seshNo=3, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.0040126806420289025
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=0.25109944798561207
# max p_fit=0.7522864730489637
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=15.53

# %%
(hazfit_B1_SNc_19, p_by_trialfit_B1_SNc_19, ltfit_B1_SNc_19) = get_fit_hazard(results, seshNo=4, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.005728118109481354
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=0.2302247688844175
# max p_fit=0.7879617642691684
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=13.19

# %%
df = results.results[1]
# Out:
# 1×17 DataFrame. Omitted printing of 17 columns
# │ Row │ │     │ ├─────┼
# │ 1   │

# %%
df.modelData[1].df[1].SessionCode[1]
# Out:
# "B1SNc13"

# %%
function composite_fit_hazard(collated_results; seshNos=[], p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true)
    
    
    hazs = []
    lts = []
    seshCodes = []
    for i = 1:length(seshNos)
        seshNo = seshNos[i]
        progressbar(i,length(seshNos))
        pprior_star = get_prior(collated_results, seshNo, :LickState)
#         println("pprior_star=", pprior_star)
        yID = collated_results.results[seshNo].modelData[1].yID[1]
        th = collated_results.results[seshNo].modelData[1].th_means[1]
        df = collated_results.results[seshNo].modelData[1].df[1]
        push!(seshCodes, df.SessionCode[1])
        X = df.X
        predictors = collated_results.results[seshNo].modelData[1].predictors # must be a vector
#         println(predictors)
        # Let's get the range of probabilities the model can do on the whole dataset...
        all_p,_ = predict_logit(yID, predictors, th, df,plotOn=false)
        min_p = minimum(all_p)
        max_p = maximum(all_p)
#         println("min p_fit=", min_p)
#         println("max p_fit=", max_p)


        trialIDs = unique(df.TrialNo)
        p_by_trial = nanmat(length(trialIDs), 1701)
        for ii =1:length(trialIDs)
            i = trialIDs[ii]
            # get the datapoints corresponding to this trial
            dps = findall(x->x==i, df.TrialNo)
            nj = ceil(Int,length(dps)/ndp_per_sample) 

            foundlick=false;
            for j = 1:nj
                mn = ndp_per_sample*(j-1)+1
                mx = round(Int,minimum([ndp_per_sample*(j), length(dps)]))
                # Average the signals within this time window...
                dpsrange = dps[mn:mx]

                # make an average dataframe of this set
                avedf = average_df(predictors[1], dpsrange, df, yID)

                # look at the DA signal and predictors at that time
                # calculate its p(move | dopamine, factors) from the model 
                prediction_p,_ = predict_logit(yID, predictors, th, avedf,plotOn=false)
                p = prediction_p[1]

                # Let's correct this p for our uncertainty. 
                #. If it's close to min prediction on our dataset, let's set to zero. 
                #. If it's close to max set close to 1
                if pre_normalize_p
                    p_corrected = (p-min_p)/max_p
                else 
                    p_corrected = p
                end
                #
                # Scale everything by the prior... (p_prior)
                #
                p_corrected = p_corrected*p_prior

                p_by_trial[ii,j] = p_corrected
            end
        end
        haz = nanmean_mat(p_by_trial)
        lt = extract_behavior_distribution(df, verbose=false)
        push!(hazs, haz)
        push!(lts, lt)
    end
    print("Finished:   ")
    pretty_print_list(seshCodes, orient="horizontal")
    return (hazs,lts,seshCodes)
end
# Out:
# composite_fit_hazard (generic function with 1 method)

# %%
(hazs,lts,seshCodes) = composite_fit_hazard(results; seshNos=B5_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
#    *---------- (1/6) 02/20/21 18:33:826
# Finished:   b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9

# %%
function haz_results_composite(hazs, lts, seshCodes; ndp_per_sample=50, normalize=true)
    fig=figure(figsize=(12,3))
    axIRT = subplot(1,3,1)
    axHaz = subplot(1,3,2)
    axOverlay = subplot(1,3,3)
    meanIRT = []
    meanHaz = []
    goodidx = findall(x->!isnan(x[1]), hazs)
    failidx = findall(x->isnan(x[1]), hazs)
    for i=1:length(goodidx)
        
        ii = goodidx[i]
        sesh=seshCodes[ii]
        # get the nanmean of the vectors
        IRTbyOP = IRT_byOpportunity(lts[ii], edges=0:0.01*ndp_per_sample:17, verbose=false)   
        xs = range(0.01, step=0.01*ndp_per_sample, stop=7)
        haz=hazs[ii]
        if normalize
            IRTbyOP = (IRTbyOP .- minimum(IRTbyOP[1:length(xs)])) ./ maximum((IRTbyOP .- minimum(IRTbyOP[1:length(xs)]))[1:length(xs)])
            haz = (haz .- minimum(haz[1:length(xs)])) ./ maximum((haz .- minimum(haz[1:length(xs)]))[1:length(xs)])
        end

        println(join([seshCodes[ii], " Rsq=", round(Rsq(IRTbyOP[1:length(xs)], haz[1:length(xs)]), digits=3)]))
        xs = range(0.01, step=0.01*ndp_per_sample, stop=7)

        edges=0:0.01*ndp_per_sample:17
        axIRT.plot(edges[1:length(xs)], IRTbyOP[1:length(xs)], linewidth=0.5, "k-", label=sesh)
        axHaz.plot(xs, haz[1:length(xs)], "r-", linewidth=0.5,label=sesh)
        axOverlay.plot(edges[1:length(xs)], IRTbyOP[1:length(xs)], linewidth=0.5, "k-", label=sesh)
        axOverlay.plot(xs, haz[1:length(xs)], "r-",linewidth=0.5, label=sesh)
        
        if i==1
            meanIRT = IRTbyOP
            meanHaz = haz
        else
            meanIRT = hcat(meanIRT, IRTbyOP)
            meanHaz = hcat(meanHaz, haz)
    
        end
    end
    # get means:
    xs = range(0.01, step=0.01*ndp_per_sample, stop=7)
    edges=0:0.01*ndp_per_sample:17
    meanIRT = nanmean_mat(meanIRT, 2)
    meanHaz = nanmean_mat(meanHaz, 2)
    
    fig.suptitle(join(["Mean Rsq=", round(Rsq(meanIRT[1:length(xs)], meanHaz[1:length(xs)]), digits=3)]), y=1.15)
    axIRT.plot(edges[1:length(xs)], meanIRT[1:length(xs)], "k-", linewidth=3, label="MEAN")
    axHaz.plot(xs, meanHaz[1:length(xs)], "r-", linewidth=3, label="MEAN")
    axOverlay.plot(edges[1:length(xs)], meanIRT[1:length(xs)], "k-", linewidth=3, label="MEAN")
    axOverlay.plot(xs, meanHaz[1:length(xs)], "r-", linewidth=3, label="MEAN")
    
    
    axIRT.set_title("True Hazard")
    axHaz.set_title("Fit Hazard")
    axOverlay.set_title("Overlay")
    
    
#     axIRT.legend(loc="bottom", bbox_to_anchor=(0, 1.3))
#     axHaz.legend(loc="bottom", bbox_to_anchor=(0, 1.3))
#     axOverlay.legend(loc="bottom", bbox_to_anchor=(0, 1.3))
    axIRT.set_xticks(0:1:7)
    axHaz.set_xticks(0:1:7)
    axOverlay.set_xticks(0:1:7)
    axIRT.set_xlim([0,7])
    axHaz.set_xlim([0,7])
    axOverlay.set_xlim([0,7])
    axIRT.set_xlabel("time (s)") 
    axHaz.set_xlabel("time (s)") 
    axOverlay.set_xlabel("time (s)") 
    axIRT.set_ylabel("normalized hazard") 
    
    # diagnostics:
    println("Good fits included: ")
    print("     ")
    pretty_print_list(seshCodes[goodidx], orient="horizontal")
    println(" ")
    println("Bad fits excluded: ")
    print("     ")
    pretty_print_list(seshCodes[failidx], orient="horizontal")
    println(" ")
    
    
    
    
end
# Out:
# haz_results_composite (generic function with 1 method)

# %%
haz_results_composite(hazs, lts, seshCodes; ndp_per_sample=50, normalize=true)
# Out:
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# b5SNc13 Rsq=0.539
# b5SNc14 Rsq=0.562
# b5SNc15 Rsq=0.555
# b5SNc9 Rsq=0.539
# Good fits included:
#      b5SNc13  b5SNc14  b5SNc15  b5SNc9
# Bad fits excluded:
#      b5SNc17  b5SNc19

# %%
(hazs_all,lts_all,seshCodes_all) = composite_fit_hazard(results; seshNos=1:98, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_all, lts_all, seshCodes_all; ndp_per_sample=50, normalize=true)

# %%
(hazs_B6,lts_B6,seshCodes_B6) = composite_fit_hazard(results; seshNos=B6_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_B6, lts_B6, seshCodes_B6; ndp_per_sample=50, normalize=true)

# %%
(hazs_H6,lts_H6,seshCodes_H6) = composite_fit_hazard(results; seshNos=H6_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H6, lts_H6, seshCodes_H6; ndp_per_sample=50, normalize=true)

# %%
(hazs_H7,lts_H7,seshCodes_H7) = composite_fit_hazard(results; seshNos=H7_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H7, lts_H7, seshCodes_H7; ndp_per_sample=50, normalize=true)

# %%
(hazs_H4,lts_H4,seshCodes_H4) = composite_fit_hazard(results; seshNos=H4_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H4, lts_H4, seshCodes_H4; ndp_per_sample=50, normalize=true)

# %%
(hazs_H5,lts_H5,seshCodes_H5) = composite_fit_hazard(results; seshNos=H5_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H5, lts_H5, seshCodes_H5; ndp_per_sample=50, normalize=true)

# %%
(hazs_H3,lts_H3,seshCodes_H3) = composite_fit_hazard(results; seshNos=H3_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H3, lts_H3, seshCodes_H3; ndp_per_sample=50, normalize=true)

# %%
(hazs_B3,lts_B3,seshCodes_B3) = composite_fit_hazard(results; seshNos=B3_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_B3, lts_B3, seshCodes_B3; ndp_per_sample=50, normalize=true)

# %%
(hazs_B1,lts_B1,seshCodes_B1) = composite_fit_hazard(results; seshNos=B1_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_B1, lts_B1, seshCodes_B1; ndp_per_sample=50, normalize=true)

# %%
(hazs_B2,lts_B2,seshCodes_B2) = composite_fit_hazard(results; seshNos=B2_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_B2, lts_B2, seshCodes_B2; ndp_per_sample=50, normalize=true)

# %%
(hazs_H14,lts_H14,seshCodes_H14) = composite_fit_hazard(results; seshNos=H14_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H14, lts_H14, seshCodes_H14; ndp_per_sample=50, normalize=true)

# %%
(hazs_H15,lts_H15,seshCodes_H15) = composite_fit_hazard(results; seshNos=H15_idx, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H15, lts_H15, seshCodes_H15; ndp_per_sample=50, normalize=true)
