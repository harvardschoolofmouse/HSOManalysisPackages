# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-20_1612) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 75:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %%
runID = "dst-15_full_B5"
pathIDx = B5_idx
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = fullmodel_ocs_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(failsb5, resultsb5,postprocessingb5) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for fm_ocs_logit_200hxdst-15_full_B5
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# ...

# %%
(hazfit_b5_13_50, p_by_trialfit_b5_13_50, ltfit_b5_13_50) = get_fit_hazard(resultsb5, seshNo=1, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.0038620354627155696
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=0.23294035507176705
# max p_fit=0.8840674412182687
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=15.92

# %%
(hazfit_b5_14_50, p_by_trialfit_b5_14_50, ltfit_b5_14_50) = get_fit_hazard(resultsb5, seshNo=2, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.003522000685490066
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=0.13053658123173226
# max p_fit=0.9910109178635247
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0306 max licktime=18.125

# %%
(hazfit_b5_15_50, p_by_trialfit_b5_15_50, ltfit_b5_15_50) = get_fit_hazard(resultsb5, seshNo=3, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.00427315412977027
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=0.21565641308296823
# max p_fit=0.929291921646847
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=18.19

# %%
(hazfit_b5_17_50, p_by_trialfit_b5_17_50, ltfit_b5_17_50) = get_fit_hazard(resultsb5, seshNo=4, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.006001052816283559
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=NaN
# max p_fit=NaN
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=14.25

# %%
(hazfit_b5_19_50, p_by_trialfit_b5_19_50, ltfit_b5_19_50) = get_fit_hazard(resultsb5, seshNo=5, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.005720692088628185
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=NaN
# max p_fit=NaN
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=13.33

# %%
(hazfit_b5_9_50, p_by_trialfit_b5_9_50, ltfit_b5_9_50) = get_fit_hazard(resultsb5, seshNo=6, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
# Out:
# pprior_star=0.004622948126767339
# [[:LickTime_2back, :Rxn_2back, :Early_2back, :Reward_2back, :ITI_2back, :LickTime_1back, :Rxn_1back, :Early_1back, :Reward_1back, :ITI_1back, :Hx10, :Hx9, :Hx8, :Hx7, :Hx6, :Hx5, :Hx4, :Hx3, :Hx2, :Y]]
# min p_fit=0.26370146217131035
# max p_fit=0.8925904058966587
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 800x300 with 2 Axes>)
# Figure(PyObject <Figure size 300x300 with 1 Axes>)
# min licktime=0.0 max licktime=11.38
