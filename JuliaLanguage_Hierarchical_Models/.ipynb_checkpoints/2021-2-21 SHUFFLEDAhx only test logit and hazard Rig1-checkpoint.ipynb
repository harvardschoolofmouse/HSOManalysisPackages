# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-21_1943) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %% [markdown]
# # The hazard predictions look so good. Need a shuffle test to see if it's just by chance...

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 75:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %%
runID = "dst-15_B6"
pathIDx = B6_idx
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = SHUFFLE_DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails, results,postprocessing) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using only a subset of these sessions:
# B6_SNc_10
# B6_SNc_11
# B6_SNc_12
# B6_SNc_13
# B6_SNc_7
# B6_SNc_9
#
# -----------------------------------------------
# Processing B6_SNc_10...(2021-02-21_1853)
#       *---------- (1/6) 02/21/21 18:53:653
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.0038324
# -0.0038324
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1189=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_10\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\th_summary_2021-02-21_1857.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_10\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\results_df_2021-02-21_1857.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_11...(2021-02-21_1857)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1001 iter=1"
# -0.047393
# -0.047393
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1125=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_11\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\th_summary_2021-02-21_1900.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_11\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\results_df_2021-02-21_1900.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_12...(2021-02-21_1900)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.016526
# -0.016526
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1147=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_12\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\th_summary_2021-02-21_1904.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_12\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\results_df_2021-02-21_1904.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_13...(2021-02-21_1904)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0099273
# -0.0099273
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 558=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_13\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\th_summary_2021-02-21_1905.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_13\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\results_df_2021-02-21_1905.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_7...(2021-02-21_1905)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.060526
# -0.060526
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 836=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_7\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\th_summary_2021-02-21_1908.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_7\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\results_df_2021-02-21_1908.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_9...(2021-02-21_1908)
#
# truncating data back: -0.15s
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 885=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_9\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\th_summary_2021-02-21_1911.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_9\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6\results_df_2021-02-21_1911.csv
# DataFrame
# -----------------------------------------------
#
# Completed procesing of 6 sessions. (2021-02-21_1911) ~
#
# 	Find results in each sessions' folder in: SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6
#
# -----------------------------------------------

# %%
filename="B6_DAHx200"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6"
figname="B6_DAHx200"
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_B6"
(hazs_B6,lts_B6,seshCodes_B6) = composite_fit_hazard(results; seshNos=1:6, p_prior=0.00386*2, 
    ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
haz_results_composite(hazs_B6, lts_B6, seshCodes_B6; ndp_per_sample=50, 
    normalize=true, figname=figname, figurePath=figpath);
# Out:
#    *---------- (1/6) 02/21/21 19:43:054
# LickState
# [[:Hx10Shuffle, :Hx9Shuffle, :Hx8Shuffle, :Hx7Shuffle, :Hx6Shuffle, :Hx5Shuffle, :Hx4Shuffle, :Hx3Shuffle, :Hx2Shuffle, :Yshuffle]]
# LickState
# [[:Hx10Shuffle, :Hx9Shuffle, :Hx8Shuffle, :Hx7Shuffle, :Hx6Shuffle, :Hx5Shuffle, :Hx4Shuffle, :Hx3Shuffle, :Hx2Shuffle, :Yshuffle]]
# LickState
# [[:Hx10Shuffle, :Hx9Shuffle, :Hx8Shuffle, :Hx7Shuffle, :Hx6Shuffle, :Hx5Shuffle, :Hx4Shuffle, :Hx3Shuffle, :Hx2Shuffle, :Yshuffle]]
# LickState
results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_1958.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_16\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_1958.csv
# DataFrame
# -----------------------------------------------
# Processing B3_SNc_17...(2021-02-21_1958)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.012894
# -0.012894
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 260=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_17\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_1958.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_17\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_1958.csv
# DataFrame
# -----------------------------------------------
# Processing B3_SNc_18...(2021-02-21_1958)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0093819
# -0.0093819
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 448=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_18\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2000.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_18\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2000.csv
# DataFrame
# -----------------------------------------------
# Processing B3_SNc_19...(2021-02-21_2000)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.01865
# -0.01865
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 436=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_19\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2001.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_19\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2001.csv
# DataFrame
# -----------------------------------------------
# Processing B3_SNc_20...(2021-02-21_2001)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0097991
# -0.0097991
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 326=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_20\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2002.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_20\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2002.csv
# DataFrame
# -----------------------------------------------
# Processing B3_SNc_21...(2021-02-21_2002)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.0040505
# 0.0040505
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 504=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_21\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2004.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_21\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2004.csv
# DataFrame
# -----------------------------------------------
# Processing B3_SNc_8...(2021-02-21_2004)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 103 iter=1"
# -0.015688
# -0.015688
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 97=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2004.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2004.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_10...(2021-02-21_2004)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.0038324
# -0.0038324
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1189=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_10\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2005.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_10\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2005.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_11...(2021-02-21_2005)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1001 iter=1"
# -0.047393
# -0.047393
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1125=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_11\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2006.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_11\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2006.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_12...(2021-02-21_2006)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.016526
# -0.016526
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1147=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_12\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2008.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_12\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2008.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_13...(2021-02-21_2008)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0099273
# -0.0099273
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 558=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_13\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2008.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_13\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2008.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_7...(2021-02-21_2008)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.060526
# -0.060526
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 836=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_7\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2009.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_7\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2009.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_9...(2021-02-21_2009)
#
# truncating data back: -0.15s
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 885=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_9\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2010.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_9\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2010.csv
# DataFrame
# -----------------------------------------------
# Processing H14_SNc_10...(2021-02-21_2010)
#
# truncating data back: -0.15s
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 715=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_10\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2012.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_10\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2012.csv
# DataFrame
# -----------------------------------------------
# Processing H14_SNc_12...(2021-02-21_2012)
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.032157
# 0.032157
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 441=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_12\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2013.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_12\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2013.csv
# DataFrame
# -----------------------------------------------
# Processing H14_SNc_14...(2021-02-21_2013)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.0024652
# -0.0024652
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 474=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_14\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2015.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_14\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2015.csv
# DataFrame
# -----------------------------------------------
# Processing H14_SNc_16...(2021-02-21_2015)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.016116
# -0.016116
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 534=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_16\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2016.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_16\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2016.csv
# DataFrame
# -----------------------------------------------
# Processing H14_SNc_18...(2021-02-21_2016)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0080779
# -0.0080779
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 443=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_18\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2017.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_18\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2017.csv
# DataFrame
# -----------------------------------------------
# Processing H14_SNc_5...(2021-02-21_2017)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.057166
# 0.057166
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 175=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_5\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2018.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_5\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2018.csv
# DataFrame
# -----------------------------------------------
# Processing H14_SNc_7...(2021-02-21_2018)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.04489
# -0.04489
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 105=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_7\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2018.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_7\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2018.csv
# DataFrame
# -----------------------------------------------
# Processing H14_SNc_8...(2021-02-21_2018)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.012986
# 0.012986
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 88=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2018.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H14_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2018.csv
# DataFrame
# -----------------------------------------------
# Processing H15_SNc_16...(2021-02-21_2018)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0042913
# -0.0042913
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 623=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_16\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2021.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_16\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2021.csv
# DataFrame
# -----------------------------------------------
# Processing H15_SNc_18...(2021-02-21_2021)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 102 iter=1"
# 0.028412
# 0.028412
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 522=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_18\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2022.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_18\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2022.csv
# DataFrame
# -----------------------------------------------
# Processing H15_SNc_5...(2021-02-21_2022)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.020418
# -0.020418
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 483=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_5\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2024.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_5\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2024.csv
# DataFrame
# -----------------------------------------------
# Processing H15_SNc_7...(2021-02-21_2024)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.027369
# -0.027369
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 353=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_7\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2025.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_7\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2025.csv
# DataFrame
# -----------------------------------------------
# Processing H15_SNc_8...(2021-02-21_2025)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.015552
# -0.015552
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 834=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2027.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H15_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2027.csv
# DataFrame
# -----------------------------------------------
# Processing H3_SNc_13...(2021-02-21_2027)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.
csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_21\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2118.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_5...(2021-02-21_2118)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.071309
# -0.071309
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 309=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_5\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2119.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_5\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2119.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_6_1...(2021-02-21_2119)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.00997
# -0.00997
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 73=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_6_1\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2119.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_6_1\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2119.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_7_1...(2021-02-21_2119)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.086747
# -0.086747
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 126=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_7_1\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2120.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_7_1\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2120.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_8...(2021-02-21_2120)
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.041328
# -0.041328
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 409=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2121.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2121.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_10...(2021-02-21_2121)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0036151
# -0.0036151
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 560=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_10\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2123.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_10\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2123.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_11...(2021-02-21_2123)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.018555
# -0.018555
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 260=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_11\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2123.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_11\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2123.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_12...(2021-02-21_2123)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0057979
# -0.0057979
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 170=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_12\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2124.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_12\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2124.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_13...(2021-02-21_2124)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.024478
# 0.024478
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 246=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_13\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2125.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_13\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2125.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_8...(2021-02-21_2125)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# 0.0022877
# 0.0022877
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1000=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2128.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_8\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2128.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_9...(2021-02-21_2128)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.014219
# -0.014219
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 919=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_9\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\th_summary_2021-02-21_2131.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_9\results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE\results_df_2021-02-21_2131.csv
# DataFrame
# -----------------------------------------------
#
# Completed procesing of 98 sessions. (2021-02-21_2131) ~
#
# 	Find results in each sessions' folder in: SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_SHUFFLE_DAHxmodel_logit_200hx_pkgdst-15_allMICE
#
# -----------------------------------------------

# %%
figpath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
savepath="N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"
# Out:
# "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_allMice"

# %%
filename="B5_DAHx200"
(hazs_B5,lts_B5,seshCodes_B5) = composite_fit_hazard(results; seshNos=B5_idx, p_prior=0.00386*2, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="B5_DAHx200"
haz_results_composite(hazs_B5, lts_B5, seshCodes_B5; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/6) 02/21/21 21:33:70
# Finished:   b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9  saving...
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# b5SNc13 Rsq=0.302
# b5SNc14 Rsq=0.355
# b5SNc15 Rsq=0.363
# b5SNc17 Rsq=0.272
# b5SNc19 Rsq=0.392
# b5SNc9 Rsq=0.495
# Good fits included:
#      b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9
# Bad fits excluded:

# %%
filename="B1_DAHx200"
(hazs_B1,lts_B1,seshCodes_B1) = composite_fit_hazard(results; seshNos=B1_idx, p_prior=0.00386*2, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="B1_DAHx200"
haz_results_composite(hazs_B1, lts_B1, seshCodes_B1; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *==-------- (1/5) 02/21/21 21:34:885
#    *====------ (2/5) 02/21/21 21:34:259
#    *======---- (3/5) 02/21/21 21:34:581
#    *========-- (4/5) 02/21/21 21:34:569
#    *========== (5/5) 02/21/21 21:34:599
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Finished:   B1SNc13  B1SNc15  B1SNc18  B1SNc19  B1SNc20  saving...
#
# B1SNc13 Rsq=0.319
# B1SNc15 Rsq=0.352
# B1SNc18 Rsq=0.29
# B1SNc19 Rsq=0.275
# B1SNc20 Rsq=0.385
# Good fits included:
#      B1SNc13  B1SNc15  B1SNc18  B1SNc19  B1SNc20
# Bad fits excluded:

# %%
filename="B2_DAHx200"
(hazs_B2,lts_B2,seshCodes_B2) = composite_fit_hazard(results; seshNos=B2_idx, p_prior=0.00386*2, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="B2_DAHx200"
haz_results_composite(hazs_B2, lts_B2, seshCodes_B2; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/8) 02/21/21 21:35:485
# Finished:   B2SNc11  B2SNc15  B2SNc17  B2SNc18  B2SNc19  B2SNc20  B2SNc21  B2SNc9  saving...
#
# B2SNc11 Rsq=0.397
# B2SNc15 Rsq=0.559
# B2SNc17 Rsq=0.349
# B2SNc18 Rsq=0.392
# B2SNc19 Rsq=0.258
# B2SNc20 Rsq=0.321
# B2SNc21 Rsq=0.303
# B2SNc9 Rsq=0.285
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Good fits included:
#      B2SNc11  B2SNc15  B2SNc17  B2SNc18  B2SNc19  B2SNc20  B2SNc21  B2SNc9
# Bad fits excluded:

# %%
filename="B3_DAHx200"
(hazs_B3,lts_B3,seshCodes_B3) = composite_fit_hazard(results; seshNos=B3_idx, p_prior=0.00386*2, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="B3_DAHx200"
haz_results_composite(hazs_B3, lts_B3, seshCodes_B3; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/11) 02/21/21 21:36:541
# Finished:   B3SNc10  B3SNc12  B3SNc14  B3SNc15  B3SNc16  B3SNc17  B3SNc18  B3SNc19  B3SNc20  B3SNc21  B3SNc8  saving...
#
# B3SNc10 Rsq=0.531
# B3SNc12 Rsq=0.283
# B3SNc14 Rsq=0.312
# B3SNc15 Rsq=0.274
# B3SNc16 Rsq=0.373
# B3SNc17 Rsq=0.452
# B3SNc18 Rsq=0.405
# B3SNc19 Rsq=0.353
# B3SNc20 Rsq=0.28
# B3SNc21 Rsq=0.344
# B3SNc8 Rsq=0.454
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Good fits included:
#      B3SNc10  B3SNc12  B3SNc14  B3SNc15  B3SNc16  B3SNc17  B3SNc18  B3SNc19  B3SNc20  B3SNc21  B3SNc8
# Bad fits excluded:

# %%
filename="B6_DAHx200"
(hazs_B6,lts_B6,seshCodes_B6) = composite_fit_hazard(results; seshNos=B6_idx, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="B6_DAHx200"
haz_results_composite(hazs_B6, lts_B6, seshCodes_B6; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/6) 02/21/21 21:36:301
# Finished:   B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9  saving...
#
# B6SNc10 Rsq=0.517
# B6SNc11 Rsq=0.506
# B6SNc12 Rsq=0.453
# B6SNc13 Rsq=0.33
# B6SNc7 Rsq=0.484
# B6SNc9 Rsq=0.346
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Good fits included:
#      B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9
# Bad fits excluded:

# %%
filename="H3_DAHx200"
(hazs_H3,lts_H3,seshCodes_H3) = composite_fit_hazard(results; seshNos=H3_idx, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="H3_DAHx200"
haz_results_composite(hazs_H3, lts_H3, seshCodes_H3; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/8) 02/21/21 21:37:085
# Finished:   H3SNc13  H3SNc15  H3SNc17  H3SNc18  H3SNc19  H3SNc20  H3SNc7  H3SNc9  saving...
#
# H3SNc13 Rsq=0.445
# H3SNc15 Rsq=0.33
# H3SNc17 Rsq=0.344
# H3SNc18 Rsq=0.458
# H3SNc19 Rsq=0.439
# H3SNc20 Rsq=0.342
# H3SNc7 Rsq=0.379
# H3SNc9 Rsq=0.355
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Good fits included:
#      H3SNc13  H3SNc15  H3SNc17  H3SNc18  H3SNc19  H3SNc20  H3SNc7  H3SNc9
# Bad fits excluded:

# %%
filename="H4_DAHx200"
(hazs_H4,lts_H4,seshCodes_H4) = composite_fit_hazard(results; seshNos=H4_idx, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="H4_DAHx200"
haz_results_composite(hazs_H4, lts_H4, seshCodes_H4; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/15) 02/21/21 21:37:622
#    *==-------- (3/15) 02/21/21 21:37:169
#    *====------ (6/15) 02/21/21 21:37:315
#    *======---- (9/15) 02/21/21 21:37:199
#    *========-- (12/15) 02/21/21 21:37:329
#    *========== (15/15) 02/21/21 21:37:046
# Finished:   H4SNc11  H4SNc13  H4SNc15  H4SNc17  H4SNc18  H4SNc19  H4SNc20  H4SNc21  H4SNc22  H4SNc23  H4SNc24  H4SNc25  H4SNc26  H4SNc7  H4SNc9  saving...
#
# H4SNc11 Rsq=0.396
# H4SNc13 Rsq=0.365
# H4SNc15 Rsq=0.337
# H4SNc17 Rsq=0.321
# H4SNc18 Rsq=0.387
# H4SNc19 Rsq=0.331
# H4SNc20 Rsq=0.37
# H4SNc21 Rsq=0.234
# H4SNc22 Rsq=0.389
# H4SNc23 Rsq=0.408
# H4SNc24 Rsq=0.388
# H4SNc25 Rsq=0.2
# H4SNc26 Rsq=0.394
# H4SNc7 Rsq=0.433
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# H4SNc9 Rsq=0.292
# Good fits included:
#      H4SNc11  H4SNc13  H4SNc15  H4SNc17  H4SNc18  H4SNc19  H4SNc20  H4SNc21  H4SNc22  H4SNc23  H4SNc24  H4SNc25  H4SNc26  H4SNc7  H4SNc9
# Bad fits excluded:

# %%
filename="H5_DAHx200"
(hazs_H5,lts_H5,seshCodes_H5) = composite_fit_hazard(results; seshNos=H5_idx, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="H5_DAHx200"
haz_results_composite(hazs_H5, lts_H5, seshCodes_H5; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/8) 02/21/21 21:38:391
# Finished:   H5SNc11  H5SNc13  H5SNc14  H5SNc15  H5SNc16  H5SNc17  H5SNc18  H5SNc19  saving...
#
# H5SNc13 Rsq=0.31
# H5SNc14 Rsq=0.286
# H5SNc15 Rsq=0.222
# H5SNc16 Rsq=0.436
# H5SNc17 Rsq=0.465
# H5SNc18 Rsq=0.582
# H5SNc19 Rsq=0.377
# Good fits included:
#      H5SNc13  H5SNc14  H5SNc15  H5SNc16  H5SNc17
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
#   H5SNc18  H5SNc19
# Bad fits excluded:
#      H5SNc11

# %%
filename="H6_DAHx200"
(hazs_H6,lts_H6,seshCodes_H6) = composite_fit_hazard(results; seshNos=H6_idx, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="H6_DAHx200"
haz_results_composite(hazs_H6, lts_H6, seshCodes_H6; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/12) 02/21/21 21:41:684
# Finished:   h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8  saving...
#
# h6SNc14 Rsq=0.374
# h6SNc15 Rsq=0.442
# h6SNc16 Rsq=0.292
# h6SNc17 Rsq=0.412
# h6SNc18 Rsq=0.316
# h6SNc19 Rsq=0.344
# h6SNc20 Rsq=0.355
# h6SNc21 Rsq=0.285
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# h6SNc5 Rsq=0.489
# h6SNc61 Rsq=0.706
# h6SNc71 Rsq=0.419
# h6SNc8 Rsq=0.413
# Good fits included:
#      h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8
# Bad fits excluded:

# %%
filename="H7_DAHx200"
(hazs_H7,lts_H7,seshCodes_H7) = composite_fit_hazard(results; seshNos=H7_idx, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="H7_DAHx200"
haz_results_composite(hazs_H7, lts_H7, seshCodes_H7; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/6) 02/21/21 21:41:978
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Finished:   h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9  saving...
#
# h7SNc10 Rsq=0.53
# h7SNc11 Rsq=0.419
# h7SNc12 Rsq=0.314
# h7SNc13 Rsq=0.236
# h7SNc8 Rsq=0.561
# h7SNc9 Rsq=0.384
# Good fits included:
#      h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9
# Bad fits excluded:

# %%
filename="H14_DAHx200"
(hazs_H14,lts_H14,seshCodes_H14) = composite_fit_hazard(results; seshNos=H14_idx, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="H14_DAHx200"
haz_results_composite(hazs_H14, lts_H14, seshCodes_H14; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *---------- (1/8) 02/21/21 21:42:177
# Finished:   H14SNc10  H14SNc12  H14SNc14  H14SNc16  H14SNc18  H14SNc5  H14SNc7  H14SNc8  saving...
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# H14SNc10 Rsq=0.472
# H14SNc12 Rsq=0.459
# H14SNc14 Rsq=0.378
# H14SNc16 Rsq=0.323
# H14SNc18 Rsq=0.356
# H14SNc5 Rsq=0.317
# H14SNc7 Rsq=0.392
# H14SNc8 Rsq=0.407
# Good fits included:
#      H14SNc10  H14SNc12  H14SNc14  H14SNc16  H14SNc18  H14SNc5  H14SNc7  H14SNc8
# Bad fits excluded:

# %%
filename="H15_DAHx200"
(hazs_H15,lts_H15,seshCodes_H15) = composite_fit_hazard(results; seshNos=H15_idx, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="H15_DAHx200"
haz_results_composite(hazs_H15, lts_H15, seshCodes_H15; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
# Out:
#    *==-------- (1/5) 02/21/21 21:42:253
#    *====------ (2/5) 02/21/21 21:42:26
#    *======---- (3/5) 02/21/21 21:42:069
#    *========-- (4/5) 02/21/21 21:42:306
#    *========== (5/5) 02/21/21 21:43:463
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Finished:   H15SNc16  H15SNc18  H15SNc5  H15SNc7  H15SNc8  saving...
#
# H15SNc16 Rsq=0.371
# H15SNc18 Rsq=0.352
# H15SNc5 Rsq=0.425
# H15SNc7 Rsq=0.483
# H15SNc8 Rsq=0.267
# Good fits included:
#      H15SNc16  H15SNc18  H15SNc5  H15SNc7  H15SNc8
# Bad fits excluded:

# %%
filename="COMPOSITE98_DAHx200"
(hazs_COMPOSITE,lts_COMPOSITE,seshCodes_COMPOSITE) = composite_fit_hazard(results; seshNos=1:98, 
            ndp_per_sample=50, pre_normalize_p=false, normalize=true, filename=filename, savepath=savepath);
figname="COMPOSITE98_DAHx200"
haz_results_composite(hazs_COMPOSITE, lts_COMPOSITE, seshCodes_COMPOSITE; ndp_per_sample=50, normalize=true, figname=figname, figurePath=figpath)
