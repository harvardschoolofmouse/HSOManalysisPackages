# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-03_1457) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 75:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %% [markdown]
# # ALL SESSIONS logit model with DA and nested history terms...
# trimmed 150ms back from lick
# fixed lickstate handling

# %%
runID = "dst-15_ALLmice"
pathIDx = []
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = nestlogit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails150, results150,postprocessing150) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for nestlogit_200hxdst-15_ALLmice
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using all these sessions.
#
# -----------------------------------------------
# Processing B1_SNc_13...(2021-02-03_1459)
#       *---------- (1/98) 02/03/21 14:59:896
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.17199
# -0.17199
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 146=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_13\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1502.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_13\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1502.csv
# -----------------------------------------------
# Processing B1_SNc_15...(2021-02-03_1502)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.08489
# 0.08489
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 125=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_15\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1503.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_15\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1503.csv
# -----------------------------------------------
# Processing B1_SNc_18...(2021-02-03_1503)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.016095
# 0.016095
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 281=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_18\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1504.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_18\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1504.csv
# -----------------------------------------------
# Processing B1_SNc_19...(2021-02-03_1504)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.015232
# -0.015232
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 478=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_19\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1506.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_19\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1506.csv
# -----------------------------------------------
# Processing B1_SNc_20...(2021-02-03_1506)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.053374
# -0.053374
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 330=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_20\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1507.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B1_SNc_20\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1507.csv
# -----------------------------------------------
# Processing B2_SNc_11...(2021-02-03_1507)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.033265
# -0.033265
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 211=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_11\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1508.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_11\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1508.csv
# -----------------------------------------------
# Processing B2_SNc_15...(2021-02-03_1508)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.095219
# -0.095219
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 240=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1508.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_15\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1508.csv
# -----------------------------------------------
# Processing B2_SNc_17...(2021-02-03_1508)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 102 iter=1"
# 0.027614
# 0.027614
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 147=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_17\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1509.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_17\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1509.csv
# -----------------------------------------------
# Processing B2_SNc_18...(2021-02-03_1509)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 10 iter=1"
# -0.035415
# -0.035415
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 60=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_18\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1509.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_18\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1509.csv
# -----------------------------------------------
# Processing B2_SNc_19...(2021-02-03_1509)
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.018065
# 0.018065
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 547=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_19\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1511.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_19\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1511.csv
# -----------------------------------------------
# Processing B2_SNc_20...(2021-02-03_1511)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.077175
# 0.077175
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 677=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_20\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1513.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_20\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1513.csv
# -----------------------------------------------
# Processing B2_SNc_21...(2021-02-03_1513)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0080102
# -0.0080102
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 344=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_21\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1514.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_21\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1514.csv
# -----------------------------------------------
# Processing B2_SNc_9...(2021-02-03_1514)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 102 iter=1"
# -0.0018768
# -0.0018768
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 221=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_9\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1515.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B2_SNc_9\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1515.csv
# -----------------------------------------------
# Processing B3_SNc_10...(2021-02-03_1515)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.097095
# -0.097095
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 138=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_10\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1515.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_10\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1515.csv
# -----------------------------------------------
# Processing B3_SNc_12...(2021-02-03_1515)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0018123
# -0.0018123
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 116=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_12\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1515.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_12\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1515.csv
# -----------------------------------------------
# Processing B3_SNc_14...(2021-02-03_1515)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# 0.046909
# 0.046909
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 297=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_14\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1516.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_14\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1516.csv
# -----------------------------------------------
# Processing B3_SNc_15...(2021-02-03_1516)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0041687
# -0.0041687
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 152=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_15\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1517.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_15\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1517.csv
# -----------------------------------------------
# Processing B3_SNc_16...(2021-02-03_1517)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.012815
# -0.012815
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 185=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_16\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1517.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_16\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1517.csv
# -----------------------------------------------
# Processing B3_SNc_17...(2021-02-03_1517)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.012894
# -0.012894
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 260=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_17\results_nestlogit_200hxdst-15_ALLmice\th_summary_2021-02-03_1518.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_17\results_nestlogit_200hxdst-15_ALLmice\results_df_2021-02-03_1518.csv
# -----------------------------------------------
# Processing B3_SNc_18...(2021-02-03_1518)
#
# truncating data back: -0.15s
#
# "!!!!!!!!!!!!!!!!!!!!!!!!!!!!! ERROR"
# "	On path N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B3_SNc_18\baseline..."
# "blmode=true  LOImode=false"
# "i=405  ystart=510  xstart=0"
# "Could not vec(readdlm(a[xstart+i], ',', Float64, '
# '));"
# "a[xstart+i-1]=10sbaseline_x_t536_fl0.21519s_B3_SNc_18.csv"
# "a[ystart+i-1]=10sbaseline_y_t536_fl0.21519s_B3_SNc_18.csv"
# "a[xstart+i]=10sbaseline_x_t537_fl0.13949s_B3_SNc_18.csv"
# "a[ystart+i]=10sbaseline_y_t537_fl0.13949s_B3_SNc_18.csv"
# 	!********* Encountered error! Skipping this directory
# at row 0, column 0 : ArgumentError("number of rows in dims must be > 0, got 0")
#
# Stacktrace:
#  [1] error(::String) at .\error.jl:33
#  [2] dlm_fill(::DataType, ::Array{Array{Int64,1},1}, ::Tuple{Int64,Int64}, ::Bool, ::String, ::Bool, ::Char) at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:514
#  [3] readdlm_string(::String, ::Char, ::Type{T} where T, ::Char, ::Bool, ::Dict{Symbol,Union{Char, Integer, Tuple{Integer,Integer}}}) at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:470
#  [4] readdlm_auto(::String, ::Char, ::Type{T} where T, ::Char, ::Bool; opts::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{,Tuple{}}}) at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:246
#  [5] readdlm_auto at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:233 [inlined]
#  [6] #readdlm#6 at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:225 [inlined]
#  [7] readdlm at C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.5\DelimitedFiles\src\DelimitedFiles.jl:225 [inlined]
#  [8] extract_data(::String; blmode::Bool, LOImode::Bool) at C:\Users\AssadLab\Documents\GitHub\HSOManalysisPackages\JuliaLanguage_Hierarchical_Models\function_library\file_modules.jl:76
#  [9] extract_data_with_baselineandLOI(::String; normalize::Bool, useHx::Bool, history_spacing_s::Float64) at C:\Users\AssadLab\Documents\GitHub\HSOManalysisPackages\JuliaLanguage_Hierarchical_Models\function_library\auto_pull_matlabdatasets.jl:353
#  [10] nestlogitrunner(::String; sessionID::String, getpackagename::Bool, runID::String, suppressFigures::Bool, history_spacing_s::Float64, modelNames::Array{String,1}, packagename::String, formulas::Array{FormulaTerm{Term,R} where R,1}) at C:\Users\AssadLab\Documents\GitHub\HSOManalysisPackages\JuliaLanguage_Hierarchical_Models\function_library\auto_pull_matlabdatasets.jl:1378
#  [11] nestlogit_200hx_pkg(::String; sessionID::String, getpackagename::Bool, runID::String, suppressFigures::Bool) at C:\Users\AssadLab\Documents\GitHub\HSOManalysisPackages\JuliaLanguage_Hierarchical_Models\function_library\auto_pull_matlabdatasets.jl:1350
#  [12] run_collated_model(::String, ::typeof(nestlogit_200hx_pkg); runID::String, pathIDx::Array{Any,1}, runFails::Bool, failDirs::Array{Any,1}, postprocessingfunction::Function, compositesavepath::String, suppressFigures::Bool) at C:\Users\AssadLab\Documents\GitHub\HSOManalysisPackages\JuliaLanguage_Hierarchical_Models\function_library\auto_pull_matlabdatasets.jl:98
#  [13] top-level scope at In[6]:7
#  [14] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
postprocresult = bootlogit_postprocessingfunction1(results150, 
    collatedPath, modelpackagefunction; runID=runID)
# Out:
# UndefVarError: results150 not defined
#
# Stacktrace:
#  [1] top-level scope at In[8]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091
