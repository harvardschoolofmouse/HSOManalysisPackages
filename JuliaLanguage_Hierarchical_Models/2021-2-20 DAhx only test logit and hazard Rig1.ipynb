# %%
cd("C:\\Users\\AssadLab\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-21_1733) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl hazard_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 75:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %%
runID = "dst-15_DAHx200_B6"
pathIDx = B6_idx
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails, results,postprocessing) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using only a subset of these sessions:
# B6_SNc_10
# B6_SNc_11
# B6_SNc_12
# B6_SNc_13
# B6_SNc_7
# B6_SNc_9
#
# -----------------------------------------------
# Processing B6_SNc_10...(2021-02-20_2312)
#       *---------- (1/6) 02/20/21 23:12:981
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.0038324
# -0.0038324
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1189=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_10\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\th_summary_2021-02-20_2314.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_10\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\results_df_2021-02-20_2314.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_11...(2021-02-20_2314)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1001 iter=1"
# -0.047393
# -0.047393
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1125=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_11\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\th_summary_2021-02-20_2316.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_11\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\results_df_2021-02-20_2316.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_12...(2021-02-20_2316)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.016526
# -0.016526
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1147=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_12\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\th_summary_2021-02-20_2318.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_12\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\results_df_2021-02-20_2318.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_13...(2021-02-20_2318)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0099273
# -0.0099273
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 558=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_13\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\th_summary_2021-02-20_2319.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_13\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\results_df_2021-02-20_2319.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_7...(2021-02-20_2319)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.060526
# -0.060526
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 836=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_7\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\th_summary_2021-02-20_2320.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_7\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\results_df_2021-02-20_2320.csv
# DataFrame
# -----------------------------------------------
# Processing B6_SNc_9...(2021-02-20_2320)
#
# truncating data back: -0.15s
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 885=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_9\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\th_summary_2021-02-20_2321.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\B6_SNc_9\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6\results_df_2021-02-20_2321.csv
# DataFrame
# -----------------------------------------------
#
# Completed procesing of 6 sessions. (2021-02-20_2321) ~
#
# 	Find results in each sessions' folder in: DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B6
#
# -----------------------------------------------

# %%
(hazs_B6,lts_B6,seshCodes_B6) = composite_fit_hazard(results; seshNos=1:6, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_B6, lts_B6, seshCodes_B6; ndp_per_sample=50, normalize=true)
# Out:
#    *---------- (1/6) 02/20/21 23:21:513
# Finished:   B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9  B6SNc10 Rsq=0.653
# B6SNc11 Rsq=0.381
# B6SNc12 Rsq=NaN
# B6SNc13 Rsq=0.741
# B6SNc7 Rsq=0.4
# B6SNc9 Rsq=0.499
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Good fits included:
#      B6SNc10  B6SNc11  B6SNc12  B6SNc13  B6SNc7  B6SNc9
# Bad fits excluded:

# %%
runID = "dst-15_DAHx200_B5"
pathIDx = B5_idx
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails5, results5,postprocessing5) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using only a subset of these sessions:
# b5_SNc_13
# b5_SNc_14
# b5_SNc_15
# b5_SNc_17
# b5_SNc_19
# b5_SNc_9
#
# -----------------------------------------------
# Processing b5_SNc_13...(2021-02-20_2324)
#       *---------- (1/6) 02/20/21 23:24:357
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.0733
# 0.0733
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 477=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_13\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\th_summary_2021-02-20_2325.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_13\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\results_df_2021-02-20_2325.csv
# DataFrame
# -----------------------------------------------
# Processing b5_SNc_14...(2021-02-20_2325)
#
# truncating data back: -0.15s
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 298=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_14\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\th_summary_2021-02-20_2325.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_14\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\results_df_2021-02-20_2325.csv
# DataFrame
# -----------------------------------------------
# Processing b5_SNc_15...(2021-02-20_2325)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.027269
# -0.027269
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 678=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_15\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\th_summary_2021-02-20_2326.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_15\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\results_df_2021-02-20_2326.csv
# DataFrame
# -----------------------------------------------
# Processing b5_SNc_17...(2021-02-20_2326)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# 0.0069683
# 0.0069683
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 855=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_17\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\th_summary_2021-02-20_2328.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_17\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\results_df_2021-02-20_2328.csv
# DataFrame
# -----------------------------------------------
# Processing b5_SNc_19...(2021-02-20_2328)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# 0.0076733
# 0.0076733
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1143=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_19\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\th_summary_2021-02-20_2330.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_19\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\results_df_2021-02-20_2330.csv
# DataFrame
# -----------------------------------------------
# Processing b5_SNc_9...(2021-02-20_2330)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.030672
# -0.030672
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 394=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_9\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\th_summary_2021-02-20_2330.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\b5_SNc_9\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5\results_df_2021-02-20_2330.csv
# DataFrame
# -----------------------------------------------
#
# Completed procesing of 6 sessions. (2021-02-20_2330) ~
#
# 	Find results in each sessions' folder in: DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_B5
#
# -----------------------------------------------

# %%
(hazs_B5,lts_B5,seshCodes_B5) = composite_fit_hazard(results5; seshNos=1:6, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_B5, lts_B5, seshCodes_B5; ndp_per_sample=50, normalize=true)
# Out:
#    *---------- (1/6) 02/20/21 23:34:752
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Finished:   b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9  b5SNc13 Rsq=0.601
# b5SNc14 Rsq=0.775
# b5SNc15 Rsq=0.717
# b5SNc17 Rsq=0.417
# b5SNc19 Rsq=0.325
# b5SNc9 Rsq=0.607
# Good fits included:
#      b5SNc13  b5SNc14  b5SNc15  b5SNc17  b5SNc19  b5SNc9
# Bad fits excluded:

# %%
runID = "dst-15_DAHx200_H6"
pathIDx = H6_idx
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails6, results6,postprocessing6) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using only a subset of these sessions:
# h6_SNc_14
# h6_SNc_15
# h6_SNc_16
# h6_SNc_17
# h6_SNc_18
# h6_SNc_19
# h6_SNc_20
# h6_SNc_21
# h6_SNc_5
# h6_SNc_6_1
# h6_SNc_7_1
# h6_SNc_8
#
# -----------------------------------------------
# Processing h6_SNc_14...(2021-02-20_2337)
#       *---------- (1/12) 02/20/21 23:37:318
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.063752
# -0.063752
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 660=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_14\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2338.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_14\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2338.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_15...(2021-02-20_2338)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.048335
# 0.048335
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 774=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_15\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2339.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_15\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2339.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_16...(2021-02-20_2339)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0077132
# -0.0077132
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 801=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_16\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2340.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_16\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2340.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_17...(2021-02-20_2340)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.057984
# 0.057984
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 611=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_17\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2341.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_17\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2341.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_18...(2021-02-20_2341)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.028998
# -0.028998
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 444=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_18\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2341.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_18\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2341.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_19...(2021-02-20_2341)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.0020488
# 0.0020488
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 374=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_19\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2342.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_19\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2342.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_20...(2021-02-20_2342)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.020356
# -0.020356
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 437=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_20\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2343.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_20\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2343.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_21...(2021-02-20_2343)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.020632
# -0.020632
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 461=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_21\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2343.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_21\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2343.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_5...(2021-02-20_2343)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.071309
# -0.071309
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 309=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_5\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2344.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_5\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2344.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_6_1...(2021-02-20_2344)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.00997
# -0.00997
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 73=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_6_1\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2344.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_6_1\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2344.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_7_1...(2021-02-20_2344)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.086747
# -0.086747
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 126=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_7_1\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2344.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_7_1\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2344.csv
# DataFrame
# -----------------------------------------------
# Processing h6_SNc_8...(2021-02-20_2344)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.041328
# -0.041328
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 409=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_8\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\th_summary_2021-02-20_2345.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_8\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6\results_df_2021-02-20_2345.csv
# DataFrame
# -----------------------------------------------
#
# Completed procesing of 12 sessions. (2021-02-20_2345) ~
#
# 	Find results in each sessions' folder in: DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H6
#
# -----------------------------------------------

# %%
(hazs_H6,lts_H6,seshCodes_H6) = composite_fit_hazard(results6; seshNos=1:12, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H6, lts_H6, seshCodes_H6; ndp_per_sample=50, normalize=true)
# Out:
#    *---------- (1/12) 02/20/21 23:45:078
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Finished:   h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8  h6SNc14 Rsq=0.382
# h6SNc15 Rsq=0.391
# h6SNc16 Rsq=0.532
# h6SNc17 Rsq=0.458
# h6SNc18 Rsq=0.411
# h6SNc19 Rsq=0.552
# h6SNc20 Rsq=0.462
# h6SNc21 Rsq=0.365
# h6SNc5 Rsq=0.484
# h6SNc61 Rsq=NaN
# h6SNc71 Rsq=0.423
# h6SNc8 Rsq=0.506
# Good fits included:
#      h6SNc14  h6SNc15  h6SNc16  h6SNc17  h6SNc18  h6SNc19  h6SNc20  h6SNc21  h6SNc5  h6SNc61  h6SNc71  h6SNc8
# Bad fits excluded:

# %%
runID = "dst-15_DAHx200_H7"
pathIDx = H7_idx
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails7, results7,postprocessing7) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using only a subset of these sessions:
# h7_SNc_10
# h7_SNc_11
# h7_SNc_12
# h7_SNc_13
# h7_SNc_8
# h7_SNc_9
#
# -----------------------------------------------
# Processing h7_SNc_10...(2021-02-20_2348)
#       *---------- (1/6) 02/20/21 23:48:267
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0036151
# -0.0036151
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 560=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_10\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\th_summary_2021-02-20_2349.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_10\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\results_df_2021-02-20_2349.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_11...(2021-02-20_2349)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.018555
# -0.018555
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 260=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_11\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\th_summary_2021-02-20_2349.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_11\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\results_df_2021-02-20_2349.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_12...(2021-02-20_2349)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0057979
# -0.0057979
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 170=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_12\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\th_summary_2021-02-20_2349.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_12\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\results_df_2021-02-20_2349.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_13...(2021-02-20_2349)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.024478
# 0.024478
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 246=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_13\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\th_summary_2021-02-20_2350.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_13\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\results_df_2021-02-20_2350.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_8...(2021-02-20_2350)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# 0.0022877
# 0.0022877
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 1000=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_8\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\th_summary_2021-02-20_2351.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_8\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\results_df_2021-02-20_2351.csv
# DataFrame
# -----------------------------------------------
# Processing h7_SNc_9...(2021-02-20_2351)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 1000 iter=1"
# -0.014219
# -0.014219
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 919=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_9\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\th_summary_2021-02-20_2353.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h7_SNc_9\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7\results_df_2021-02-20_2353.csv
# DataFrame
# -----------------------------------------------
#
# Completed procesing of 6 sessions. (2021-02-20_2353) ~
#
# 	Find results in each sessions' folder in: DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H7
#
# -----------------------------------------------

# %%
(hazs_H7,lts_H7,seshCodes_H7) = composite_fit_hazard(results7; seshNos=1:6, p_prior=0.00386*2, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H7, lts_H7, seshCodes_H7; ndp_per_sample=50, normalize=true)
# Out:
#    *---------- (1/6) 02/20/21 23:53:06
# Finished:   h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9  h7SNc10 Rsq=0.609
# h7SNc11 Rsq=0.423
# h7SNc12 Rsq=0.538
# h7SNc13 Rsq=0.319
# h7SNc8 Rsq=0.383
# h7SNc9 Rsq=0.388
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# Good fits included:
#      h7SNc10  h7SNc11  h7SNc12  h7SNc13  h7SNc8  h7SNc9
# Bad fits excluded:

# %%
runID = "dst-15_DAHx200_H4"
pathIDx = H4_idx
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = DAHxmodel_logit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails4, results4,postprocessing4) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using only a subset of these sessions:
# H4_SNc_11
# H4_SNc_13
# H4_SNc_15
# H4_SNc_17
# H4_SNc_18
# H4_SNc_19
# H4_SNc_20
# H4_SNc_21
# H4_SNc_22
# H4_SNc_23
# H4_SNc_24
# H4_SNc_25
# H4_SNc_26
# H4_SNc_7
# H4_SNc_9
#
# -----------------------------------------------
# Processing H4_SNc_11...(2021-02-20_2356)
#       *---------- (1/15) 02/20/21 23:56:411
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 102 iter=1"
# -0.073441
# -0.073441
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 320=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_11\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2357.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_11\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2357.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_13...(2021-02-20_2357)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.0076489
# -0.0076489
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 196=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_13\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2357.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_13\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2357.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_15...(2021-02-20_2357)
#       *==-------- (3/15) 02/20/21 23:57:073
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.03269
# -0.03269
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 146=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_15\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2357.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_15\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2357.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_17...(2021-02-20_2357)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.061299
# 0.061299
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 381=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_17\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2357.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_17\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2357.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_18...(2021-02-20_2357)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.039953
# 0.039953
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 353=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_18\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2358.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_18\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2358.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_19...(2021-02-20_2358)
#       *====------ (6/15) 02/20/21 23:58:197
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.048401
# -0.048401
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 330=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_19\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2358.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_19\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2358.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_20...(2021-02-20_2358)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.04945
# -0.04945
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 284=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_20\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2358.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_20\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2358.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_21...(2021-02-20_2358)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0019422
# -0.0019422
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 441=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_21\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2359.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_21\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2359.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_22...(2021-02-20_2359)
#       *======---- (9/15) 02/20/21 23:59:624
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.00069147
# 0.00069147
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 531=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_22\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-20_2359.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_22\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-20_2359.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_23...(2021-02-20_2359)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0062892
# -0.0062892
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 558=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_23\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-21_0000.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_23\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-21_0000.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_24...(2021-02-21_0000)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.012365
# -0.012365
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 250=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_24\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-21_0000.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_24\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-21_0000.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_25...(2021-02-21_0000)
#       *========-- (12/15) 02/21/21 00:00:592
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.045779
# 0.045779
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 524=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_25\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-21_0001.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_25\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-21_0001.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_26...(2021-02-21_0001)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.05687
# -0.05687
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 518=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_26\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-21_0001.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_26\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-21_0001.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_7...(2021-02-21_0001)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# 0.16939
# 0.16939
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 156=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_7\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-21_0002.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_7\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-21_0002.csv
# DataFrame
# -----------------------------------------------
# Processing H4_SNc_9...(2021-02-21_0002)
#       *========== (15/15) 02/21/21 00:02:012
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.0076582
# 0.0076582
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 195=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_9\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\th_summary_2021-02-21_0002.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\H4_SNc_9\results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4\results_df_2021-02-21_0002.csv
# DataFrame
# -----------------------------------------------
#
# Completed procesing of 15 sessions. (2021-02-21_0002) ~
#
# 	Find results in each sessions' folder in: DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_DAHxmodel_logit_200hx_pkgdst-15_DAHx200_H4
#
# -----------------------------------------------

# %%
(hazs_H4,lts_H4,seshCodes_H4) = composite_fit_hazard(results4; seshNos=1:15, ndp_per_sample=50, pre_normalize_p=false, normalize=true);
haz_results_composite(hazs_H4, lts_H4, seshCodes_H4; ndp_per_sample=50, normalize=true)
# Out:
#    *---------- (1/15) 02/21/21 00:20:297
#    *==-------- (3/15) 02/21/21 00:20:186
#    *====------ (6/15) 02/21/21 00:20:227
#    *======---- (9/15) 02/21/21 00:20:80
#    *========-- (12/15) 02/21/21 00:20:415
#    *========== (15/15) 02/21/21 00:20:907
# Finished:   H4SNc11  H4SNc13  H4SNc15  H4SNc17  H4SNc18  H4SNc19  H4SNc20  H4SNc21  H4SNc22  H4SNc23  H4SNc24  H4SNc25  H4SNc26  H4SNc7  H4SNc9
# Figure(PyObject <Figure size 1200x300 with 3 Axes>)
# H4SNc11 Rsq=0.486
# H4SNc13 Rsq=0.438
# H4SNc15 Rsq=NaN
# H4SNc17 Rsq=0.465
# H4SNc18 Rsq=0.358
# H4SNc19 Rsq=0.345
# H4SNc20 Rsq=0.469
# H4SNc21 Rsq=0.459
# H4SNc22 Rsq=0.483
# H4SNc23 Rsq=0.479
# H4SNc24 Rsq=0.602
# H4SNc25 Rsq=0.344
# H4SNc26 Rsq=0.585
# H4SNc7 Rsq=0.405
# H4SNc9 Rsq=0.466
# Good fits included:
#      H4SNc11  H4SNc13  H4SNc15  H4SNc17  H4SNc18  H4SNc19  H4SNc20  H4SNc21  H4SNc22  H4SNc23  H4SNc24  H4SNc25  H4SNc26  H4SNc7  H4SNc9
# Bad fits excluded:
