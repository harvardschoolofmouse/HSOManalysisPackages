# %%
cd("C:\\Users\\DollahDollahBillz\\Documents\\GitHub\\HSOManalysisPackages\\JuliaLanguage_Hierarchical_Models")
include(join([pwd(), "\\function_library\\file_modules.jl"]))
refresh_tools("function_library")
# Out:
# Refreshed (2021-02-03_1452) GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl

# %%
cd("N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh")

# %%
B1_idx = 1:5
B2_idx = 6:13
B3_idx = 14:24
B5_idx = 75:80
B6_idx = 25:30
H3_idx = 44:51
H4_idx = 52:66
H5_idx = 67:74
H6_idx = 81:92
H7_idx = 93:98
H14_idx = 31:38
H15_idx = 39:43
# Out:
# 39:43

# %% [markdown]
# # H6 logit model with DA and nested history terms...
# trimmed 150ms back from lick
# fixed lickstate handling

# %%
runID = "dst-15_H6"
pathIDx = H6_idx
collatedPath = "N:\\Assad Lab\\allison\\Collated Analyses\\JULIA_CSVs\\All_SNc_nosplitsesh"
modelpackagefunction = nestlogit_200hx_pkg
postprocessingfunction = template_postprocessingfunction#bootlogit_timeslice_postprocessingfunction1

(fails150_H6, results150_H6,postprocessing150_H6) = run_collated_model(collatedPath, 
    modelpackagefunction; pathIDx = pathIDx,runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath="", runID=runID, suppressFigures=true);
# Out:
# -----------------------------------------------
#
# Initializing run_collated_model for nestlogit_200hxdst-15_H6
#
# Found 98 sessions in N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using only a subset of these sessions:
# h6_SNc_14
# h6_SNc_15
# h6_SNc_16
# h6_SNc_17
# h6_SNc_18
# h6_SNc_19
# h6_SNc_20
# h6_SNc_21
# h6_SNc_5
# h6_SNc_6_1
# h6_SNc_7_1
# h6_SNc_8
#
# -----------------------------------------------
# Processing h6_SNc_14...(2021-02-03_1453)
#       *---------- (1/12) 02/03/21 14:53:271
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.063752
# -0.063752
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 660=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_14\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1454.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_14\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1454.csv
# -----------------------------------------------
# Processing h6_SNc_15...(2021-02-03_1455)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.048335
# 0.048335
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 774=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_15\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1504.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_15\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1504.csv
# -----------------------------------------------
# Processing h6_SNc_16...(2021-02-03_1504)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.0077132
# -0.0077132
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 801=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_16\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1508.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_16\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1508.csv
# -----------------------------------------------
# Processing h6_SNc_17...(2021-02-03_1508)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.057984
# 0.057984
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 611=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_17\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1510.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_17\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1510.csv
# -----------------------------------------------
# Processing h6_SNc_18...(2021-02-03_1510)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.028998
# -0.028998
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 444=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_18\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1512.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_18\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1512.csv
# -----------------------------------------------
# Processing h6_SNc_19...(2021-02-03_1512)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# 0.0020488
# 0.0020488
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 374=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_19\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1514.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_19\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1514.csv
# -----------------------------------------------
# Processing h6_SNc_20...(2021-02-03_1514)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.020356
# -0.020356
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 437=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_20\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1516.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_20\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1516.csv
# -----------------------------------------------
# Processing h6_SNc_21...(2021-02-03_1516)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.020632
# -0.020632
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 461=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_21\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1517.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_21\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1517.csv
# -----------------------------------------------
# Processing h6_SNc_5...(2021-02-03_1517)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.071309
# -0.071309
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 309=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_5\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1519.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_5\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1519.csv
# -----------------------------------------------
# Processing h6_SNc_6_1...(2021-02-03_1519)
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.00997
# -0.00997
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 73=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_6_1\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1520.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_6_1\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1520.csv
# -----------------------------------------------
# Processing h6_SNc_7_1...(2021-02-03_1520)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 101 iter=1"
# -0.086747
# -0.086747
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 126=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_7_1\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1542.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_7_1\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1542.csv
# -----------------------------------------------
# Processing h6_SNc_8...(2021-02-03_1542)
#
# truncating data back: -0.15s
# "     WARNING: The end of baseline is same as begin of LOI on tNo 100 iter=1"
# -0.041328
# -0.041328
# "     WARNING: NB that we are normalizing history separate from in-trial dopamine..."
# Downsampling the no-lick state => using 409=n, the number of first-licks
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_8\results_nestlogit_200hxdst-15_H6\th_summary_2021-02-03_1547.csv
# saving...
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh\h6_SNc_8\results_nestlogit_200hxdst-15_H6\results_df_2021-02-03_1547.csv
# -----------------------------------------------
#
# Completed procesing of 12 sessions. (2021-02-03_1547) ~
#
# 	Find results in each sessions' folder in: nestlogit_200hxdst-15_H6
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# 	This is a template postprocessingfunction. To do work, you need to
# 		implement what you want to collate from the results here!
# Post-modeling collation of results complete and variables saved to:
# N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\Collated_results_nestlogit_200hxdst-15_H6
#
# -----------------------------------------------

# %%
postprocresult = bootlogit_postprocessingfunction1(results150_H6, 
    collatedPath, modelpackagefunction; runID=runID)
# Out:
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 500x300 with 1 Axes>)
# Figure(PyObject <Figure size 2000x300 with 3 Axes>)
# Figure(PyObject <Figure size 2000x300 with 3 Axes>)
# Figs saved to:N:\Assad Lab\allison\Collated Analyses\JULIA_CSVs\All_SNc_nosplitsesh
# Nothing
