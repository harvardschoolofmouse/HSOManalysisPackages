# %% [markdown]
# # Ok! Trying the pre-packaged logit model!
#
# Because REPL was being stupid about @formula not being defined, running everything in Jupyter-Notebook.

# %%
# run_logit_model_1.jl

# USER MUST SET THESE:
collatedPath = "/Volumes/Neurobio/Assad Lab/allison/Collated Analyses/JULIA_CSVs/All_SNc_nosplitsesh"
compositesavepath="" # the save directory will be formed automagically!
runID = 1 # set runID nonZero to specify which run it is.

# Use the latest versions of our files and dependencies!
cd("/Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models")
include("/Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/file_modules.jl")
refresh_tools("/Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library", exact=true)
println("	")
# CANNED FOR LOGIT:
modelpackagefunction = bootlogit_modelpackage1
postprocessingfunction = bootlogit_postprocessingfunction1

warning("suppressing figures from individual sessions, but they will still be saved to host folders for that session.")
println("	")
(fails, results) = run_collated_model(collatedPath, modelpackagefunction; pathIDx = [],runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath=compositesavepath, runID=runID, suppressFigures=true);
# Out:
# Refreshed GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl
# ********************************************************************************************
#      WARNING: suppressing figures from individual sessions, but they will still be saved to host folders for that session.
# ********************************************************************************************
#
# -----------------------------------------------
#
# Initializing run_collated_model for bootlogit_modelpackage1_8757
#
# Found 98 sessions in /Volumes/Neurobio/Assad Lab/allison/Collated Analyses/JULIA_CSVs/All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using all these sessions.
#
# -----------------------------------------------
# Processing B1_SNc_13...(2021-01-26_0025)
#       *---------- (1/98) 01/26/21 00:25:885
#
# Used smote to estimate the number of up/down sampling needed => using 450=n
#    *---------- (1/100) 01/26/21 00:26:069
# 	!********* Encountered error! Skipping this directory
# PosDefException: matrix is not positive definite; Cholesky factorization failed.
#
# Stacktrace:
#  [1] checkpositivedefinite at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.5/LinearAlgebra/src/factorization.jl:18 [inlined]
#  [2] cholesky!(::Hermitian{Float64,Array{Float64,2}}, ::Val{false}; check::Bool) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.5/LinearAlgebra/src/cholesky.jl:219
#  [3] cholesky! at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.5/LinearAlgebra/src/cholesky.jl:218 [inlined] (repeats 2 times)
#  [4] delbeta!(::GLM.DensePredChol{Float64,Cholesky{Float64,Array{Float64,2}}}, ::Array{Float64,1}, ::Array{Float64,1}) at /Users/lilis/.julia/packages/GLM/dbJFe/src/linpred.jl:153
#  [5] _fit!(::GeneralizedLinearModel{GLM.GlmResp{Array{Float64,1},Binomial{Float64},ProbitLink},GLM.DensePredChol{Float64,Cholesky{Float64,Array{Float64,2}}}}, ::Bool, ::Int64, ::Float64, ::Float64, ::Float64, ::Nothing) at /Users/lilis/.julia/packages/GLM/dbJFe/src/glmfit.jl:307
#  [6] #fit!#12 at /Users/lilis/.julia/packages/GLM/dbJFe/src/glmfit.jl:373 [inlined]
#  [7] fit! at /Users/lilis/.julia/packages/GLM/dbJFe/src/glmfit.jl:353 [inlined]
#  [8] fit(::Type{GeneralizedLinearModel}, ::Array{Float64,2}, ::BitArray{1}, ::Binomial{Float64}, ::ProbitLink; dofit::Bool, wts::BitArray{1}, offset::BitArray{1}, fitargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{,Tuple{}}}) at /Users/lilis/.julia/packages/GLM/dbJFe/src/glmfit.jl:469
#  [9] fit(::Type{GeneralizedLinearModel}, ::Array{Float64,2}, ::BitArray{1}, ::Binomial{Float64}, ::ProbitLink) at /Users/lilis/.julia/packages/GLM/dbJFe/src/glmfit.jl:463
#  [10] fit(::Type{GeneralizedLinearModel}, ::FormulaTerm{Term,Term}, ::DataFrame, ::Binomial{Float64}, ::Vararg{Any,N} where N; contrasts::Dict{Symbol,Any}, kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{,Tuple{}}}) at /Users/lilis/.julia/packages/StatsModels/Oreif/src/statsmodel.jl:88
#  [11] fit(::Type{GeneralizedLinearModel}, ::FormulaTerm{Term,Term}, ::DataFrame, ::Binomial{Float64}, ::ProbitLink) at /Users/lilis/.julia/packages/StatsModels/Oreif/src/statsmodel.jl:82
#  [12] #glm#16 at /Users/lilis/.julia/packages/GLM/dbJFe/src/glmfit.jl:485 [inlined]
#  [13] glm at /Users/lilis/.julia/packages/GLM/dbJFe/src/glmfit.jl:485 [inlined]
#  [14] build_and_report_logit_model(::FormulaTerm{Term,Term}, ::DataFrame, ::DataFrame; modelName::String, modelClass::String, verbose::Bool, figurePath::String) at /Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/modeling_tools.jl:174
#  [15] modelSelectionByAICBICxval(::DataFrame, ::Symbol, ::Array{FormulaTerm{Term,R} where R,1}, ::Array{String,1}, ::String; n_iters::Int64, updownsampleYID::Bool, figurePath::String, savePath::String, suppressFigures::Bool) at /Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/modeling_tools.jl:1592
#  [16] bootlogit_modelpackage1(::String; sessionID::String, getpackagename::Bool, runID::Int64, suppressFigures::Bool) at /Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/auto_pull_matlabdatasets.jl:281
#  [17] run_collated_model(::String, ::typeof(bootlogit_modelpackage1); runID::Int64, pathIDx::Array{Any,1}, runFails::Bool, failDirs::Array{Any,1}, postprocessingfunction::Function, compositesavepath::String, suppressFigures::Bool) at /Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/auto_pull_matlabdatasets.jl:98
#  [18] top-level scope at In[4]:18
#  [19] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
