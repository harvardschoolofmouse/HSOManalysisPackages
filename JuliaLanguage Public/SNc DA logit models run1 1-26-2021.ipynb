# %% [markdown]
# # Ok! Trying the pre-packaged logit model!
#
# Because REPL was being stupid about @formula not being defined, running everything in Jupyter-Notebook.

# %%
# run_logit_model_1.jl

# USER MUST SET THESE:
collatedPath = "/Volumes/Neurobio/Assad Lab/allison/Collated Analyses/JULIA_CSVs/All_SNc_nosplitsesh"
compositesavepath="" # the save directory will be formed automagically!
runID = 1 # set runID nonZero to specify which run it is.

# Use the latest versions of our files and dependencies!
cd("/Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models")
include("/Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/file_modules.jl")
refresh_tools("/Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library", exact=true)
println("	")
# CANNED FOR LOGIT:
modelpackagefunction = bootlogit_modelpackage1
postprocessingfunction = bootlogit_postprocessingfunction1

warning("suppressing figures from individual sessions, but they will still be saved to host folders for that session.")
println("	")
(fails, results) = run_collated_model(collatedPath, modelpackagefunction; pathIDx = [],runFails=false, failDirs=[], postprocessingfunction=postprocessingfunction,
    compositesavepath=compositesavepath, runID=runID, suppressFigures=true);
# Out:
# Refreshed GLMNet_tools.jl auto_pull_matlabdatasets.jl cluster_modules.jl feedback_modules.jl file_modules.jl math_modules.jl modeling_tools.jl plotting_tools.jl probabilistic_modules.jl
# ********************************************************************************************
#      WARNING: suppressing figures from individual sessions, but they will still be saved to host folders for that session.
# ********************************************************************************************
#
# -----------------------------------------------
#
# Initializing run_collated_model for bootlogit_modelpackage1_1
#
# Found 98 sessions in /Volumes/Neurobio/Assad Lab/allison/Collated Analyses/JULIA_CSVs/All_SNc_nosplitsesh:
# 1. B1_SNc_13
# 2. B1_SNc_15
# 3. B1_SNc_18
# 4. B1_SNc_19
# 5. B1_SNc_20
# 6. B2_SNc_11
# 7. B2_SNc_15
# 8. B2_SNc_17
# 9. B2_SNc_18
# 10. B2_SNc_19
# 11. B2_SNc_20
# 12. B2_SNc_21
# 13. B2_SNc_9
# 14. B3_SNc_10
# 15. B3_SNc_12
# 16. B3_SNc_14
# 17. B3_SNc_15
# 18. B3_SNc_16
# 19. B3_SNc_17
# 20. B3_SNc_18
# 21. B3_SNc_19
# 22. B3_SNc_20
# 23. B3_SNc_21
# 24. B3_SNc_8
# 25. B6_SNc_10
# 26. B6_SNc_11
# 27. B6_SNc_12
# 28. B6_SNc_13
# 29. B6_SNc_7
# 30. B6_SNc_9
# 31. H14_SNc_10
# 32. H14_SNc_12
# 33. H14_SNc_14
# 34. H14_SNc_16
# 35. H14_SNc_18
# 36. H14_SNc_5
# 37. H14_SNc_7
# 38. H14_SNc_8
# 39. H15_SNc_16
# 40. H15_SNc_18
# 41. H15_SNc_5
# 42. H15_SNc_7
# 43. H15_SNc_8
# 44. H3_SNc_13
# 45. H3_SNc_15
# 46. H3_SNc_17
# 47. H3_SNc_18
# 48. H3_SNc_19
# 49. H3_SNc_20
# 50. H3_SNc_7
# 51. H3_SNc_9
# 52. H4_SNc_11
# 53. H4_SNc_13
# 54. H4_SNc_15
# 55. H4_SNc_17
# 56. H4_SNc_18
# 57. H4_SNc_19
# 58. H4_SNc_20
# 59. H4_SNc_21
# 60. H4_SNc_22
# 61. H4_SNc_23
# 62. H4_SNc_24
# 63. H4_SNc_25
# 64. H4_SNc_26
# 65. H4_SNc_7
# 66. H4_SNc_9
# 67. H5_SNc_11
# 68. H5_SNc_13
# 69. H5_SNc_14
# 70. H5_SNc_15
# 71. H5_SNc_16
# 72. H5_SNc_17
# 73. H5_SNc_18
# 74. H5_SNc_19
# 75. b5_SNc_13
# 76. b5_SNc_14
# 77. b5_SNc_15
# 78. b5_SNc_17
# 79. b5_SNc_19
# 80. b5_SNc_9
# 81. h6_SNc_14
# 82. h6_SNc_15
# 83. h6_SNc_16
# 84. h6_SNc_17
# 85. h6_SNc_18
# 86. h6_SNc_19
# 87. h6_SNc_20
# 88. h6_SNc_21
# 89. h6_SNc_5
# 90. h6_SNc_6_1
# 91. h6_SNc_7_1
# 92. h6_SNc_8
# 93. h7_SNc_10
# 94. h7_SNc_11
# 95. h7_SNc_12
# 96. h7_SNc_13
# 97. h7_SNc_8
# 98. h7_SNc_9
# 	Using all these sessions.
#
# -----------------------------------------------
# Processing B1_SNc_13...(2021-01-26_0041)
#       *---------- (1/98) 01/26/21 00:41:045
#
# Used smote to estimate the number of up/down sampling needed => using 450=n
#    *---------- (1/100) 01/26/21 00:41:02
# ***PosDefException...retrying. (1/10)
# ***PosDefException...retrying. (2/10)
# ***PosDefException...retrying. (3/10)
# ***PosDefException...retrying. (4/10)
# ***PosDefException...retrying. (5/10)
# ***PosDefException...retrying. (6/10)
# ***PosDefException...retrying. (7/10)
# ***PosDefException...retrying. (8/10)
# ***PosDefException...retrying. (9/10)
# ********************************************************************************************
#      WARNING: PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ********************************************************************************************
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B1_SNc_15...(2021-01-26_0041)
#
# Used smote to estimate the number of up/down sampling needed => using 375=n
#    *---------- (1/100) 01/26/21 00:42:731
# ********************************************************************************************
#      WARNING: Expected CImin=-35.04372247739675 but got -35.04529396488464
# ********************************************************************************************
#    *=--------- (10/100) 01/26/21 00:42:437
#    *==-------- (20/100) 01/26/21 00:42:437
#    *===------- (30/100) 01/26/21 00:42:437
#    *====------ (40/100) 01/26/21 00:42:438
#    *=====----- (50/100) 01/26/21 00:42:438
#    *======---- (60/100) 01/26/21 00:42:438
#    *=======--- (70/100) 01/26/21 00:42:438
#    *========-- (80/100) 01/26/21 00:42:438
#    *=========- (90/100) 01/26/21 00:42:438
#    *========== (100/100) 01/26/21 00:42:438
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B1_SNc_18...(2021-01-26_0042)
#
# Used smote to estimate the number of up/down sampling needed => using 894=n
#    *---------- (1/100) 01/26/21 00:44:30
#    *=--------- (10/100) 01/26/21 00:44:349
#    *==-------- (20/100) 01/26/21 00:44:349
#    *===------- (30/100) 01/26/21 00:44:349
#    *====------ (40/100) 01/26/21 00:44:349
#    *=====----- (50/100) 01/26/21 00:44:349
#    *======---- (60/100) 01/26/21 00:44:35
#    *=======--- (70/100) 01/26/21 00:44:35
#    *========-- (80/100) 01/26/21 00:44:35
#    *=========- (90/100) 01/26/21 00:44:35
#    *========== (100/100) 01/26/21 00:44:35
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B1_SNc_19...(2021-01-26_0044)
#
# Used smote to estimate the number of up/down sampling needed => using 1581=n
#    *---------- (1/100) 01/26/21 00:46:761
#    *=--------- (10/100) 01/26/21 00:46:836
#    *==-------- (20/100) 01/26/21 00:46:836
#    *===------- (30/100) 01/26/21 00:46:836
#    *====------ (40/100) 01/26/21 00:46:836
#    *=====----- (50/100) 01/26/21 00:46:836
#    *======---- (60/100) 01/26/21 00:46:836
#    *=======--- (70/100) 01/26/21 00:46:837
#    *========-- (80/100) 01/26/21 00:46:837
#    *=========- (90/100) 01/26/21 00:46:837
#    *========== (100/100) 01/26/21 00:46:837
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B1_SNc_20...(2021-01-26_0046)
#
# Used smote to estimate the number of up/down sampling needed => using 1044=n
#    *---------- (1/100) 01/26/21 00:48:549
# ***PosDefException...retrying. (1/10)
# ***PosDefException...retrying. (2/10)
# ***PosDefException...retrying. (3/10)
# ***PosDefException...retrying. (4/10)
# ***PosDefException...retrying. (5/10)
# ***PosDefException...retrying. (6/10)
# ***PosDefException...retrying. (7/10)
# ***PosDefException...retrying. (8/10)
# ***PosDefException...retrying. (9/10)
# ********************************************************************************************
#      WARNING: PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ********************************************************************************************
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B2_SNc_11...(2021-01-26_0048)
#
# Used smote to estimate the number of up/down sampling needed => using 636=n
#    *---------- (1/100) 01/26/21 00:49:053
# ***PosDefException...retrying. (1/10)
# ***PosDefException...retrying. (2/10)
# ***PosDefException...retrying. (3/10)
# ***PosDefException...retrying. (4/10)
# ***PosDefException...retrying. (5/10)
# ***PosDefException...retrying. (6/10)
# ***PosDefException...retrying. (7/10)
# ***PosDefException...retrying. (8/10)
# ***PosDefException...retrying. (9/10)
# ********************************************************************************************
#      WARNING: PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ********************************************************************************************
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B2_SNc_15...(2021-01-26_0049)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B2_SNc_17...(2021-01-26_0050)
#
# Used smote to estimate the number of up/down sampling needed => using 441=n
#    *---------- (1/100) 01/26/21 00:51:762
# ***PosDefException...retrying. (1/10)
# ***PosDefException...retrying. (2/10)
# ***PosDefException...retrying. (3/10)
# ***PosDefException...retrying. (4/10)
# ***PosDefException...retrying. (5/10)
# ***PosDefException...retrying. (6/10)
# ***PosDefException...retrying. (7/10)
# ***PosDefException...retrying. (8/10)
# ***PosDefException...retrying. (9/10)
# ********************************************************************************************
#      WARNING: PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ********************************************************************************************
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B2_SNc_18...(2021-01-26_0051)
# Used smote to estimate the number of up/down sampling needed => using 180=n
#    *---------- (1/100) 01/26/21 00:51:218
# ********************************************************************************************
#      WARNING: Expected CImin=-0.3349559926398744 but got -0.33500661611008786
# ********************************************************************************************
# ***PosDefException...retrying. (1/10)
# ********************************************************************************************
#      WARNING: Expected CImin=-0.06499301220708531 but got -0.06506193296941543
# ********************************************************************************************
# ***PosDefException...retrying. (2/10)
# ***PosDefException...retrying. (3/10)
# ***PosDefException...retrying. (4/10)
# ***PosDefException...retrying. (5/10)
# ***PosDefException...retrying. (6/10)
# ***PosDefException...retrying. (7/10)
# ***PosDefException...retrying. (8/10)
# ***PosDefException...retrying. (9/10)
# ********************************************************************************************
#      WARNING: PosDefException -- Matrix could not fit after 10 attempts at up/down sampling. Ignoring this set!
# ********************************************************************************************
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B2_SNc_19...(2021-01-26_0051)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B2_SNc_20...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B2_SNc_21...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B2_SNc_9...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_10...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_12...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_14...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_15...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_16...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_17...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_18...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_19...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_20...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_21...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B3_SNc_8...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B6_SNc_10...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B6_SNc_11...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B6_SNc_12...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B6_SNc_13...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B6_SNc_7...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing B6_SNc_9...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H14_SNc_10...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H14_SNc_12...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H14_SNc_14...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H14_SNc_16...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H14_SNc_18...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H14_SNc_5...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H14_SNc_7...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H14_SNc_8...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H15_SNc_16...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H15_SNc_18...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H15_SNc_5...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H15_SNc_7...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H15_SNc_8...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H3_SNc_13...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H3_SNc_15...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H3_SNc_17...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H3_SNc_18...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H3_SNc_19...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H3_SNc_20...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H3_SNc_7...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H3_SNc_9...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_11...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_13...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_15...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_17...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_18...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_19...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_20...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_21...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_22...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_23...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_24...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_25...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_26...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_7...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H4_SNc_9...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H5_SNc_11...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H5_SNc_13...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H5_SNc_14...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H5_SNc_15...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H5_SNc_16...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H5_SNc_17...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H5_SNc_18...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing H5_SNc_19...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing b5_SNc_13...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing b5_SNc_14...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing b5_SNc_15...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing b5_SNc_17...(2021-01-26_0053)
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing b5_SNc_19...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing b5_SNc_9...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_14...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_15...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_16...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_17...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_18...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_19...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_20...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_21...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_5...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_6_1...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_7_1...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h6_SNc_8...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h7_SNc_10...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h7_SNc_11...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h7_SNc_12...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h7_SNc_13...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h7_SNc_8...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
# Processing h7_SNc_9...(2021-01-26_0053)
#
# 	!********* Encountered error! Skipping this directory
#
# -----------------------------------------------
#
# Completed procesing of 0 sessions. (2021-01-26_0053) ~
#
# 	Find results in each sessions' folder in: bootlogit_modelpackage1_1
# /Volumes/Neurobio/Assad Lab/allison/Collated Analyses/JULIA_CSVs/All_SNc_nosplitsesh
#
# Initiating post-modeling collation of results...
# BoundsError: attempt to access 0-element Array{DataFrame,1} at index [1]
#
# Stacktrace:
#  [1] getindex(::Array{DataFrame,1}, ::Int64) at ./array.jl:809
#  [2] combine_th_across_sessions(::DataFrame, ::String, ::Int64, ::String) at /Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/auto_pull_matlabdatasets.jl:328
#  [3] bootlogit_postprocessingfunction1(::DataFrame, ::String, ::Function; runID::Int64) at /Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/auto_pull_matlabdatasets.jl:309
#  [4] run_collated_model(::String, ::typeof(bootlogit_modelpackage1); runID::Int64, pathIDx::Array{Any,1}, runFails::Bool, failDirs::Array{Any,1}, postprocessingfunction::Function, compositesavepath::String, suppressFigures::Bool) at /Users/lilis/Documents/GitHub/HSOManalysisPackages/JuliaLanguage_Hierarchical_Models/function_library/auto_pull_matlabdatasets.jl:120
#  [5] top-level scope at In[1]:19
#  [6] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
